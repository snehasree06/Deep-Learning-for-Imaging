# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn 
import torchvision
import torchvision.transforms as transforms

# %%
print(torch.__version__)
# Out:
# 1.13.0.dev20220624

# %%
input_size = 784 # 28x28
hidden_layer1= 500 
hidden_layer2=250
hidden_layer3=100
num_classes = 10
num_epochs = 15
batch_size = 64
learning_rate = 0.15

# %%
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(),  download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

# %%
def convert_to_onehot(labels,num_classes):
    output = np.eye(num_classes)[np.array(labels).reshape(-1)]
    return output.reshape(list(np.shape(labels))+[num_classes])

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

def relu(x):
    return np.maximum(0, x)

def softmax(x):
    return np.exp(x)/sum(np.exp(x))

# %%
def sigmoid_derivative(x):
    return sigmoid(x) * (1- sigmoid(x))

def relu_derivative(x):
    return x>0

def softmax_derivative(x):

    return softmax(x)*(1-softmax(x))

# %%
def init_weights(No,Ni):
    M=np.sqrt(6/(Ni+No))
    weights=np.asarray(np.random.uniform(-M, M, (No, Ni)), dtype=np.float64)
    biases  = np.zeros((No,1))
    return weights,biases

# %%
def initialize_parameters(layers_dims):
    w1,b1=init_weights(layers_dims[1],layers_dims[0])
    w2,b2=init_weights(layers_dims[2],layers_dims[1])
    w3,b3=init_weights(layers_dims[3],layers_dims[2])
    w4,b4=init_weights(layers_dims[4],layers_dims[3])
    parameters={
    "w1":w1,
    "w2":w2,
    "w3":w3,
    "w4":w4,
    "b1":b1,
    "b2":b2,
    "b3":b3,
    "b4":b4
    }
    return parameters

# %%
def forward_propagation(X,parameters):
    w1=parameters['w1']
    b1=parameters['b1']
    w2=parameters['w2']
    b2=parameters['b2']
    w3=parameters['w3']
    b3=parameters['b3']
    w4=parameters['w4']
    b4=parameters['b4']
    Z1=np.dot(w1,X.T)+b1
    A1=sigmoid(Z1)
    Z2 = np.dot(w2,A1) + b2
    A2=sigmoid(Z2)
    Z3 = np.dot(w3,A2) + b3
    A3=sigmoid(Z3)
    Z4=np.dot(w4,A3)+b4
    A4=softmax(Z4)
    cache = {
        "Z1" : Z1,
        "Z2" : Z2,
        "Z3" : Z3,
        "Z4" : Z4,
        "A1" : A1,
        "A2" : A2,
        "A3" : A3,
        "A4" : A4,
        "w1" : w1,
        "b1" : b1,
        "w2" : w2,
        "b2" : b2,
        "w3" : w3,
        "b3" : b3,
        "w4" : w4,
        "b4" : b4  
    }
    return A4,cache

# %%
def compute_cost(A, Y):    
    #A is predicted
    #Y is actual
    m = Y.shape[1] 
    logprobs = np.multiply(-np.log(A),Y) + np.multiply(-np.log(1 - A), 1 - Y)
    cost = 1./m * np.nansum(logprobs)
    return cost

# %%
def backward_propagation(X, Y, cache):
    m = X.shape[1]
    A4=cache['A4']
    A3=cache['A3']
    A2=cache['A2']
    A1=cache['A1']
    Z3=cache['Z3']
    Z4=cache['Z4']
    Z2=cache['Z2']
    Z1=cache['Z1']
    w1=cache['w1']
    b1=cache['b1']
    w2=cache['w2']
    b2=cache['b2']
    w3=cache['w3']
    b3=cache['b3']
    w4=cache['w4']
    b4=cache['b4']

    dZ4 = A4 - Y
    dW4 = 1./m * np.dot(dZ4, A3.T)
    db4 = 1./m * np.sum(dZ4, axis=1, keepdims = True)
    
    dA3 = np.dot(w4.T, dZ4)
    dZ3 = np.multiply(dA3, sigmoid_derivative(Z3))
    dW3 = 1./m * np.dot(dZ3, A2.T)
    db3 = 1./m * np.sum(dZ3, axis=1, keepdims = True)
    
    dA2 = np.dot(w3.T, dZ3)
    dZ2 = np.multiply(dA2, sigmoid_derivative(Z2))
    dW2 = 1./m * np.dot(dZ2, A1.T)
    db2 = 1./m * np.sum(dZ2, axis=1, keepdims = True)

    dA1 = np.dot(w2.T, dZ2)
    dZ1 = np.multiply(dA1, sigmoid_derivative(Z1))
    dW1 = 1./m * np.dot(dZ1, X)
    db1 = 1./m * np.sum(dZ1, axis=1, keepdims = True)

    
    gradients = {"dZ4": dZ4, "dW4": dW4, "db4": db4,
                 "dA3": dA3, "dZ3": dZ3, "dW3": dW3, "db3": db3,
                 "dA2": dA2, "dZ2": dZ2, "dW2": dW2, "db2": db2,
                 "dA1": dA1, "dZ1": dZ1, "dW1": dW1, "db1": db1}
    
    return gradients

# %%
def update_parameter(parameters,gradients,learning_rate):
    w1=parameters['w1']
    b1=parameters['b1']
    w2=parameters['w2']
    b2=parameters['b2']
    w3=parameters['w3']
    b3=parameters['b3']
    w4=parameters['w4']
    b4=parameters['b4']
    dW1=gradients['dW1']
    db1=gradients['db1']
    dW2=gradients['dW2']
    db2=gradients['db2']
    dW3=gradients['dW3']
    db3=gradients['db3']
    dW4=gradients['dW4']
    db4=gradients['db4']
    w1 = w1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    w2 = w2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2
    w3 = w3 - learning_rate * dW3
    b3 = b3 - learning_rate * db3
    w4 = w4 - learning_rate * dW4
    b4 = b4 - learning_rate * db4
    
    updated_parameters={
    "w1":w1,
    "w2":w2,
    "w3":w3,
    "w4":w4,
    "b1":b1,
    "b2":b2,
    "b3":b3,
    "b4":b4
    }
    return updated_parameters

# %%
def find_accuracy(y_actual,y_pred):
    accuracy = np.count_nonzero(np.argmax(y_pred,axis=0)==np.argmax(y_actual,axis=1))/y_actual.shape[0]
    return accuracy

# %%
def predict(X,Y,parameters):
    y_pred,cache=forward_propagation(X,parameters)
    return y_pred

# %%
def model1(dataset,layers_dims,num_epochs):
    m=len(dataset)
    num_batches=m/batch_size
    parameters=initialize_parameters(layers_dims)
    costs=[]
    acc=[]
    for epoch in range(num_epochs):
        for i in range(int(num_batches)):
            # Data loader
            loader = torch.utils.data.DataLoader(dataset=dataset,batch_size = batch_size ,shuffle=True)
            dataiter = iter(loader)
            data = next(dataiter)
            X,y = data
            X=X.numpy()
            y=y.numpy()
            # Flatten the images
            image_vector_size = 28*28
            X = X.reshape(X.shape[0], image_vector_size)
            y_one_hot=convert_to_onehot(y,num_classes)
            y_pred,cache=forward_propagation(X,parameters)
            cost=compute_cost(y_pred,y_one_hot.T)
            gradients=backward_propagation(X,y_one_hot.T,cache)
            parameters=update_parameter(parameters,gradients,learning_rate)
            if i%20==0:
                print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{int(num_batches)}], Loss: {cost.item():.4f}')
                costs.append(cost)
                acc.append(find_accuracy(y_one_hot,y_pred))
    return acc,costs,parameters

# %%
layers_dims=[784,500,250,100,10]
train_acc,train_costs,trained_parameters=model1(train_dataset,layers_dims,15)
# Out:
# Epoch [1/15], Step [1/937], Loss: 3.6028
# Epoch [1/15], Step [21/937], Loss: 3.1887
# Epoch [1/15], Step [41/937], Loss: 3.3035
# Epoch [1/15], Step [61/937], Loss: 3.2434
# Epoch [1/15], Step [81/937], Loss: 3.2804
# Epoch [1/15], Step [101/937], Loss: 3.2331
# Epoch [1/15], Step [121/937], Loss: 3.2474
# Epoch [1/15], Step [141/937], Loss: 3.2426
# Epoch [1/15], Step [161/937], Loss: 3.2392
# Epoch [1/15], Step [181/937], Loss: 3.2389
# Epoch [1/15], Step [201/937], Loss: 3.2638
# Epoch [1/15], Step [221/937], Loss: 3.2211
# Epoch [1/15], Step [241/937], Loss: 3.2503
# Epoch [1/15], Step [261/937], Loss: 3.2408
# Epoch [1/15], Step [281/937], Loss: 3.2477
# Epoch [1/15], Step [301/937], Loss: 3.2445
# Epoch [1/15], Step [321/937], Loss: 3.2441
# Epoch [1/15], Step [341/937], Loss: 3.2652
# Epoch [1/15], Step [361/937], Loss: 3.2462
# Epoch [1/15], Step [381/937], Loss: 3.2584
# Epoch [1/15], Step [401/937], Loss: 3.2357
# Epoch [1/15], Step [421/937], Loss: 3.2558
# Epoch [1/15], Step [441/937], Loss: 3.2363
# Epoch [1/15], Step [461/937], Loss: 3.2675
# Epoch [1/15], Step [481/937], Loss: 3.2515
# Epoch [1/15], Step [501/937], Loss: 3.2422
# Epoch [1/15], Step [521/937], Loss: 3.2344
# Epoch [1/15], Step [541/937], Loss: 3.2493
# Epoch [1/15], Step [561/937], Loss: 3.2372
# Epoch [1/15], Step [581/937], Loss: 3.2608
# Epoch [1/15], Step [601/937], Loss: 3.2549
# Epoch [1/15], Step [621/937], Loss: 3.2328
# Epoch [1/15], Step [641/937], Loss: 3.2166
# Epoch [1/15], Step [661/937], Loss: 3.2501
# Epoch [1/15], Step [681/937], Loss: 3.2463
# Epoch [1/15], Step [701/937], Loss: 3.2463
# Epoch [1/15], Step [721/937], Loss: 3.2252
# Epoch [1/15], Step [741/937], Loss: 3.2488
# Epoch [1/15], Step [761/937], Loss: 3.2460
# Epoch [1/15], Step [781/937], Loss: 3.2413
# Epoch [1/15], Step [801/937], Loss: 3.2370
# Epoch [1/15], Step [821/937], Loss: 3.2381
# Epoch [1/15], Step [841/937], Loss: 3.2344
# Epoch [1/15], Step [861/937], Loss: 3.2397
# Epoch [1/15], Step [881/937], Loss: 3.2335
# Epoch [1/15], Step [901/937], Loss: 3.2421
# Epoch [1/15], Step [921/937], Loss: 3.2267
# Epoch [2/15], Step [1/937], Loss: 3.2259
# Epoch [8/15], Step [161/937], Loss: 2.1437
# Epoch [8/15], Step [181/937], Loss: 1.9432
# Epoch [8/15], Step [201/937], Loss: 2.0601
# Epoch [8/15], Step [221/937], Loss: 2.0418
# Epoch [8/15], Step [241/937], Loss: 2.0731
# Epoch [8/15], Step [261/937], Loss: 2.1555
# Epoch [8/15], Step [281/937], Loss: 2.0472
# Epoch [8/15], Step [301/937], Loss: 1.9216
# Epoch [8/15], Step [321/937], Loss: 2.0286
# Epoch [8/15], Step [341/937], Loss: 1.8566
# Epoch [8/15], Step [361/937], Loss: 1.9785
# Epoch [8/15], Step [381/937], Loss: 1.9858
# Epoch [8/15], Step [401/937], Loss: 2.0203
# Epoch [8/15], Step [421/937], Loss: 2.1414
# Epoch [8/15], Step [441/937], Loss: 2.0900
# Epoch [8/15], Step [461/937], Loss: 2.1523
# Epoch [8/15], Step [481/937], Loss: 1.8986
# Epoch [8/15], Step [501/937], Loss: 2.1358
# Epoch [8/15], Step [521/937], Loss: 1.9661
# Epoch [8/15], Step [541/937], Loss: 1.9664
# Epoch [8/15], Step [561/937], Loss: 1.9257
# Epoch [8/15], Step [581/937], Loss: 1.9665
# Epoch [8/15], Step [601/937], Loss: 2.0370
# Epoch [8/15], Step [621/937], Loss: 1.9479
# Epoch [8/15], Step [641/937], Loss: 1.8878
# Epoch [8/15], Step [661/937], Loss: 1.9998
# Epoch [8/15], Step [681/937], Loss: 1.9674
# Epoch [8/15], Step [701/937], Loss: 1.7476
# Epoch [8/15], Step [721/937], Loss: 1.8555
# Epoch [8/15], Step [741/937], Loss: 1.7412
# Epoch [8/15], Step [761/937], Loss: 1.9586
# Epoch [8/15], Step [781/937], Loss: 1.8717
# Epoch [8/15], Step [801/937], Loss: 1.9063
# Epoch [8/15], Step [821/937], Loss: 1.7002
# Epoch [8/15], Step [841/937], Loss: 1.9495
# Epoch [8/15], Step [861/937], Loss: 1.8638
# Epoch [8/15], Step [881/937], Loss: 1.9519
# Epoch [8/15], Step [901/937], Loss: 1.9905
# Epoch [8/15], Step [921/937], Loss: 1.8420
# Epoch [9/15], Step [1/937], Loss: 1.8452
# Epoch [9/15], Step [21/937], Loss: 1.8657
# Epoch [9/15], Step [41/937], Loss: 1.8543
# Epoch [9/15], Step [61/937], Loss: 2.0428
# Epoch [9/15], Step [81/937], Loss: 1.8097
# Epoch [9/15], Step [101/937], Loss: 1.8804
# Epoch [9/15], Step [121/937], Loss: 1.9075
# Epoch [9/15], Step [141/937], Loss: 1.8209
# Epoch [9/15], Step [161/937], Loss: 1.8339
# Epoch [9/15], Step [181/937], Loss: 1.7675
# Epoch [9/15], Step [201/937], Loss: 1.9454
# Epoch [9/15], Step [221/937], Loss: 1.6346
# Epoch [9/15], Step [241/937], Loss: 1.6506
# Epoch [9/15], Step [261/937], Loss: 1.9102
# Epoch [9/15], Step [281/937], Loss: 1.7151
# Epoch [9/15], Step [301/937], Loss: 1.7954
# Epoch [9/15], Step [321/937], Loss: 1.6981
# Epoch [9/15], Step [341/937], Loss: 1.8943
# Epoch [9/15], Step [361/937], Loss: 1.8264
# Epoch [9/15], Step [381/937], Loss: 1.6748
# Epoch [9/15], Step [401/937], Loss: 1.7690
# Epoch [9/15], Step [421/937], Loss: 1.7590
# Epoch [9/15], Step [441/937], Loss: 1.8149
# Epoch [9/15], Step [461/937], Loss: 1.5769
# Epoch [9/15], Step [481/937], Loss: 1.9466
# Epoch [9/15], Step [501/937], Loss: 1.8715
# Epoch [9/15], Step [521/937], Loss: 1.7129
# Epoch [9/15], Step [541/937], Loss: 1.6899
# Epoch [9/15], Step [561/937], Loss: 1.7647
# Epoch [9/15], Step [581/937], Loss: 1.7168
# Epoch [9/15], Step [601/937], Loss: 1.7236
# Epoch [9/15], Step [621/937], Loss: 1.6095
# Epoch [9/15], Step [641/937], Loss: 1.7841
# Epoch [9/15], Step [661/937], Loss: 1.4999
# Epoch [9/15], Step [681/937], Loss: 1.7615
# Epoch [9/15], Step [701/937], Loss: 1.7062
# Epoch [9/15], Step [721/937], Loss: 1.6440
# Epoch [9/15], Step [741/937], Loss: 1.5011
# Epoch [9/15], Step [761/937], Loss: 1.7526
# Epoch [9/15], Step [781/937], Loss: 1.3980
# Epoch [9/15], Step [801/937], Loss: 1.4898
# Epoch [9/15], Step [821/937], Loss: 1.7628
# Epoch [9/15], Step [841/937], Loss: 1.6501
# Epoch [9/15], Step [861/937], Loss: 1.5027
# Epoch [9/15], Step [881/937], Loss: 1.6056
# Epoch [9/15], Step [901/937], Loss: 1.5535
# Epoch [9/15], Step [921/937], Loss: 1.7755
# Epoch [10/15], Step [1/937], Loss: 1.7475
# Epoch [10/15], Step [21/937], Loss: 1.5592
# Epoch [10/15], Step [41/937], Loss: 1.5483
# Epoch [10/15], Step [61/937], Loss: 1.4772
# Epoch [10/15], Step [81/937], Loss: 1.6535
# Epoch [10/15], Step [101/937], Loss: 1.5688
# Epoch [10/15], Step [121/937], Loss: 1.6861
# Epoch [10/15], Step [141/937], Loss: 1.6157
# Epoch [10/15], Step [161/937], Loss: 1.4272
# Epoch [10/15], Step [181/937], Loss: 1.5541
# Epoch [10/15], Step [201/937], Loss: 1.5059
# Epoch [10/15], Step [221/937], Loss: 1.3623
# Epoch [10/15], Step [241/937], Loss: 1.4740
# Epoch [10/15], Step [261/937], Loss: 1.3197
# Epoch [10/15], Step [281/937], Loss: 1.6026
# Epoch [10/15], Step [301/937], Loss: 1.7345
# Epoch [10/15], Step [321/937], Loss: 1.6681
# Epoch [10/15], Step [341/937], Loss: 1.4775
# Epoch [10/15], Step [361/937], Loss: 1.5849
# Epoch [10/15], Step [381/937], Loss: 1.6159
# Epoch [10/15], Step [401/937], Loss: 1.5787
# Epoch [10/15], Step [421/937], Loss: 1.5083
# Epoch [10/15], Step [441/937], Loss: 1.4771
# Epoch [10/15], Step [461/937], Loss: 1.5711
# Epoch [10/15], Step [481/937], Loss: 1.3556
# Epoch [10/15], Step [501/937], Loss: 1.4183
# Epoch [10/15], Step [521/937], Loss: 1.5934
# Epoch [10/15], Step [541/937], Loss: 1.4871
# Epoch [10/15], Step [561/937], Loss: 1.4638
# Epoch [13/15], Step [81/937], Loss: 0.8337
# Epoch [13/15], Step [101/937], Loss: 1.1968
# Epoch [13/15], Step [121/937], Loss: 1.0672
# Epoch [13/15], Step [141/937], Loss: 1.0593
# Epoch [13/15], Step [161/937], Loss: 0.8922
# Epoch [13/15], Step [181/937], Loss: 1.0392
# Epoch [13/15], Step [201/937], Loss: 1.1498
# Epoch [13/15], Step [221/937], Loss: 1.1639
# Epoch [13/15], Step [241/937], Loss: 1.3622
# Epoch [13/15], Step [261/937], Loss: 1.0702
# Epoch [13/15], Step [281/937], Loss: 1.3466
# Epoch [13/15], Step [301/937], Loss: 0.9408
# Epoch [13/15], Step [321/937], Loss: 0.9987
# Epoch [13/15], Step [341/937], Loss: 1.1047
# Epoch [13/15], Step [361/937], Loss: 0.9026
# Epoch [13/15], Step [381/937], Loss: 1.1182
# Epoch [13/15], Step [401/937], Loss: 1.0793
# Epoch [13/15], Step [421/937], Loss: 0.9572
# Epoch [13/15], Step [441/937], Loss: 1.1700
# Epoch [13/15], Step [461/937], Loss: 1.0080
# Epoch [13/15], Step [481/937], Loss: 1.0465
# Epoch [13/15], Step [501/937], Loss: 1.2553
# Epoch [13/15], Step [521/937], Loss: 1.2000
# Epoch [13/15], Step [541/937], Loss: 1.1636
# Epoch [13/15], Step [561/937], Loss: 1.2081
# Epoch [13/15], Step [581/937], Loss: 1.2518
# Epoch [13/15], Step [601/937], Loss: 1.1290
# Epoch [13/15], Step [621/937], Loss: 1.4489
# Epoch [13/15], Step [641/937], Loss: 0.9881
# Epoch [13/15], Step [661/937], Loss: 1.0754
# Epoch [13/15], Step [681/937], Loss: 1.1530
# Epoch [13/15], Step [701/937], Loss: 1.1889
# Epoch [13/15], Step [721/937], Loss: 1.1590
# Epoch [13/15], Step [741/937], Loss: 0.9925
# Epoch [13/15], Step [761/937], Loss: 1.1604
# Epoch [13/15], Step [781/937], Loss: 1.4064
# Epoch [13/15], Step [801/937], Loss: 1.0904
# Epoch [13/15], Step [821/937], Loss: 1.0468
# Epoch [13/15], Step [841/937], Loss: 1.2390
# Epoch [13/15], Step [861/937], Loss: 1.0272
# Epoch [13/15], Step [881/937], Loss: 1.2486
# Epoch [13/15], Step [901/937], Loss: 0.9806
# Epoch [13/15], Step [921/937], Loss: 1.0080
# Epoch [14/15], Step [1/937], Loss: 1.0410
# Epoch [14/15], Step [21/937], Loss: 1.1881
# Epoch [14/15], Step [41/937], Loss: 1.2955
# Epoch [14/15], Step [61/937], Loss: 1.0007
# Epoch [14/15], Step [81/937], Loss: 1.1739
# Epoch [14/15], Step [101/937], Loss: 1.1410
# Epoch [14/15], Step [121/937], Loss: 1.0750
# Epoch [14/15], Step [141/937], Loss: 1.2056
# Epoch [14/15], Step [161/937], Loss: 1.1045
# Epoch [14/15], Step [181/937], Loss: 1.0355
# Epoch [14/15], Step [201/937], Loss: 1.0241
# Epoch [14/15], Step [221/937], Loss: 0.7850
# Epoch [14/15], Step [241/937], Loss: 1.1192
# Epoch [14/15], Step [261/937], Loss: 1.1994
# Epoch [14/15], Step [281/937], Loss: 1.2711
# Epoch [15/15], Step [501/937], Loss: 0.9867
# Epoch [15/15], Step [521/937], Loss: 0.9272
# Epoch [15/15], Step [541/937], Loss: 0.8892
# Epoch [15/15], Step [561/937], Loss: 1.0103
# Epoch [15/15], Step [581/937], Loss: 0.9717
# Epoch [15/15], Step [601/937], Loss: 1.0820
# Epoch [15/15], Step [621/937], Loss: 0.9426
# Epoch [15/15], Step [641/937], Loss: 0.8772
# Epoch [15/15], Step [661/937], Loss: 0.9882
# Epoch [15/15], Step [681/937], Loss: 0.9723
# Epoch [15/15], Step [701/937], Loss: 0.8825
# Epoch [15/15], Step [721/937], Loss: 1.0418
# Epoch [15/15], Step [741/937], Loss: 0.8827
# Epoch [15/15], Step [761/937], Loss: 0.9111
# Epoch [15/15], Step [781/937], Loss: 1.1041
# Epoch [15/15], Step [801/937], Loss: 0.9490
# Epoch [15/15], Step [821/937], Loss: 0.9836
# Epoch [15/15], Step [841/937], Loss: 0.9330
# Epoch [15/15], Step [861/937], Loss: 0.7496
# Epoch [15/15], Step [881/937], Loss: 0.7675
# Epoch [15/15], Step [901/937], Loss: 1.0508
# Epoch [15/15], Step [921/937], Loss: 0.8449

# %%
p=len(test_dataset)
test_batches=p/batch_size
loader = torch.utils.data.DataLoader(dataset=test_dataset,batch_size = p ,shuffle=True)
dataiter = iter(loader)
data = next(dataiter)
X,y = data

X=X.numpy()
y=y.numpy()
# Flatten the images
image_vector_size = 28*28
X = X.reshape(X.shape[0], image_vector_size)
y_one_hot=convert_to_onehot(y,num_classes)
y_hat,out_cache=forward_propagation(X,trained_parameters)
test_accuracy=find_accuracy(y_one_hot,y_hat)
test_cost=compute_cost(y_hat,y_one_hot.T)

# %%
import seaborn as sn
from sklearn.metrics import confusion_matrix
k = np.argmax(y_hat,axis=0)
cm=confusion_matrix(k, y)
plt.figure(figsize=(8,8))
sn.heatmap(confusion_matrix(k, y),annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('truth')
# Out:
# Text(51.0, 0.5, 'truth')

# %%
plt.plot(train_costs)
plt.xlabel('train loss')
plt.ylabel('number of iterations')
plt.title('Train loss with sigmoid activation and learning rate 0.15')
plt.show()

# %%
plt.plot(train_acc)
plt.xlabel('train accuracy')
plt.ylabel('number of iterations')
plt.title('Train accuracy with sigmoid activation and learning rate 0.15')
plt.show()

# %%
m=len(train_dataset)
train_batches=m/batch_size

loader = torch.utils.data.DataLoader(dataset=train_dataset,batch_size = m ,shuffle=True)
dataiter = iter(loader)
data = next(dataiter)
X_train,y_train = data

X_train=X_train.numpy()
y_train=y_train.numpy()
# Flatten the images
image_vector_size = 28*28
X_train = X_train.reshape(X_train.shape[0], image_vector_size)
y_train_one_hot=convert_to_onehot(y_train,num_classes)
y_train_hat,out_train_cache=forward_propagation(X_train,trained_parameters)

train_accuracy_final=find_accuracy(y_train_one_hot,y_train_hat)
train_cost_final=compute_cost(y_train_hat,y_train_one_hot.T)

# %%
print(train_accuracy_final)
# Out:
# 0.8472166666666666

# %%
print(train_acc[-1])
# Out:
# 0.84375

# %%
print(test_accuracy)
# Out:
# 0.8476
