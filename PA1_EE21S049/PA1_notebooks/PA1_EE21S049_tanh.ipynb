# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn 
import torchvision
import torchvision.transforms as transforms

# %%
print(torch.__version__)
# Out:
# 1.13.0.dev20220624

# %%
input_size = 784 # 28x28
hidden_layer1= 500 
hidden_layer2=250
hidden_layer3=100
num_classes = 10
num_epochs = 15
batch_size = 64
learning_rate = 0.1

# %%
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(),  download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

# %%
def convert_to_onehot(labels,num_classes):
    output = np.eye(num_classes)[np.array(labels).reshape(-1)]
    return output.reshape(list(np.shape(labels))+[num_classes])

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

def relu(x):
    return np.maximum(0, x)

def softmax(x):
    return np.exp(x)/sum(np.exp(x))

def tanh(x):
    y=(np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x))
    return y

# %%
def sigmoid_derivative(x):
    return sigmoid(x) * (1- sigmoid(x))

def relu_derivative(x):
    return x>0

def softmax_derivative(x):

    return softmax(x)*(1-softmax(x))

def tanh_derivative(x):
    y=tanh(x)
    return (1-y**2)

# %%
def init_weights(No,Ni):
    M=np.sqrt(6/(Ni+No))
    weights=np.asarray(np.random.uniform(-M, M, (No, Ni)), dtype=np.float64)
    biases  = np.zeros((No,1))
    return weights,biases

# %%
def initialize_parameters(layers_dims):
    w1,b1=init_weights(layers_dims[1],layers_dims[0])
    w2,b2=init_weights(layers_dims[2],layers_dims[1])
    w3,b3=init_weights(layers_dims[3],layers_dims[2])
    w4,b4=init_weights(layers_dims[4],layers_dims[3])
    parameters={
    "w1":w1,
    "w2":w2,
    "w3":w3,
    "w4":w4,
    "b1":b1,
    "b2":b2,
    "b3":b3,
    "b4":b4
    }
    return parameters

# %%
def forward_propagation(X,parameters):
    w1=parameters['w1']
    b1=parameters['b1']
    w2=parameters['w2']
    b2=parameters['b2']
    w3=parameters['w3']
    b3=parameters['b3']
    w4=parameters['w4']
    b4=parameters['b4']
    Z1=np.dot(w1,X.T)+b1
    A1=tanh(Z1)
    Z2 = np.dot(w2,A1) + b2
    A2=tanh(Z2)
    Z3 = np.dot(w3,A2) + b3
    A3=tanh(Z3)
    Z4=np.dot(w4,A3)+b4
    A4=softmax(Z4)
    cache = {
        "Z1" : Z1,
        "Z2" : Z2,
        "Z3" : Z3,
        "Z4" : Z4,
        "A1" : A1,
        "A2" : A2,
        "A3" : A3,
        "A4" : A4,
        "w1" : w1,
        "b1" : b1,
        "w2" : w2,
        "b2" : b2,
        "w3" : w3,
        "b3" : b3,
        "w4" : w4,
        "b4" : b4  
    }
    return A4,cache

# %%
def compute_cost(A, Y):    
    #A is predicted
    #Y is actual
    m = Y.shape[1] 
    logprobs = np.multiply(-np.log(A),Y) + np.multiply(-np.log(1 - A), 1 - Y)
    cost = 1./m * np.nansum(logprobs)
    return cost

# %%
def backward_propagation(X, Y, cache):
    m = X.shape[1]
    A4=cache['A4']
    A3=cache['A3']
    A2=cache['A2']
    A1=cache['A1']
    Z3=cache['Z3']
    Z4=cache['Z4']
    Z2=cache['Z2']
    Z1=cache['Z1']
    w1=cache['w1']
    b1=cache['b1']
    w2=cache['w2']
    b2=cache['b2']
    w3=cache['w3']
    b3=cache['b3']
    w4=cache['w4']
    b4=cache['b4']

    dZ4 = A4 - Y
    dW4 = 1./m * np.dot(dZ4, A3.T)
    db4 = 1./m * np.sum(dZ4, axis=1, keepdims = True)
    
    dA3 = np.dot(w4.T, dZ4)
    dZ3 = np.multiply(dA3, tanh_derivative(Z3))
    dW3 = 1./m * np.dot(dZ3, A2.T)
    db3 = 1./m * np.sum(dZ3, axis=1, keepdims = True)
    
    dA2 = np.dot(w3.T, dZ3)
    dZ2 = np.multiply(dA2, tanh_derivative(Z2))
    dW2 = 1./m * np.dot(dZ2, A1.T)
    db2 = 1./m * np.sum(dZ2, axis=1, keepdims = True)

    dA1 = np.dot(w2.T, dZ2)
    dZ1 = np.multiply(dA1, tanh_derivative(Z1))
    dW1 = 1./m * np.dot(dZ1, X)
    db1 = 1./m * np.sum(dZ1, axis=1, keepdims = True)

    
    gradients = {"dZ4": dZ4, "dW4": dW4, "db4": db4,
                 "dA3": dA3, "dZ3": dZ3, "dW3": dW3, "db3": db3,
                 "dA2": dA2, "dZ2": dZ2, "dW2": dW2, "db2": db2,
                 "dA1": dA1, "dZ1": dZ1, "dW1": dW1, "db1": db1}
    
    return gradients

# %%
def update_parameter(parameters,gradients,learning_rate):
    w1=parameters['w1']
    b1=parameters['b1']
    w2=parameters['w2']
    b2=parameters['b2']
    w3=parameters['w3']
    b3=parameters['b3']
    w4=parameters['w4']
    b4=parameters['b4']
    dW1=gradients['dW1']
    db1=gradients['db1']
    dW2=gradients['dW2']
    db2=gradients['db2']
    dW3=gradients['dW3']
    db3=gradients['db3']
    dW4=gradients['dW4']
    db4=gradients['db4']
    w1 = w1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    w2 = w2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2
    w3 = w3 - learning_rate * dW3
    b3 = b3 - learning_rate * db3
    w4 = w4 - learning_rate * dW4
    b4 = b4 - learning_rate * db4
    
    updated_parameters={
    "w1":w1,
    "w2":w2,
    "w3":w3,
    "w4":w4,
    "b1":b1,
    "b2":b2,
    "b3":b3,
    "b4":b4
    }
    return updated_parameters

# %%
def find_accuracy(y_actual,y_pred):
    accuracy = np.count_nonzero(np.argmax(y_pred,axis=0)==np.argmax(y_actual,axis=1))/y_actual.shape[0]
    return accuracy

# %%
def predict(X,Y,parameters):
    y_pred,cache=forward_propagation(X,parameters)
    return y_pred

# %%
def model1(dataset,layers_dims,num_epochs):
    m=len(dataset)
    num_batches=m/batch_size
    parameters=initialize_parameters(layers_dims)
    costs=[]
    acc=[]
    for epoch in range(num_epochs):
        for i in range(int(num_batches)):
            # Data loader
            loader = torch.utils.data.DataLoader(dataset=dataset,batch_size = batch_size ,shuffle=True)
            dataiter = iter(loader)
            data = next(dataiter)
            X,y = data
            X=X.numpy()
            y=y.numpy()
            # Flatten the images
            image_vector_size = 28*28
            X = X.reshape(X.shape[0], image_vector_size)
            y_one_hot=convert_to_onehot(y,num_classes)
            y_pred,cache=forward_propagation(X,parameters)
            cost=compute_cost(y_pred,y_one_hot.T)
            gradients=backward_propagation(X,y_one_hot.T,cache)
            parameters=update_parameter(parameters,gradients,learning_rate)
            if i%20==0:
                print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{int(num_batches)}], Loss: {cost.item():.4f}')
                costs.append(cost)
                acc.append(find_accuracy(y_one_hot,y_pred))
    return acc,costs,parameters

# %%
layers_dims=[784,500,250,100,10]
train_acc,train_costs,trained_parameters=model1(train_dataset,layers_dims,15)
# Out:
# Epoch [1/15], Step [1/937], Loss: 3.2602
# Epoch [1/15], Step [21/937], Loss: 2.7894
# Epoch [1/15], Step [41/937], Loss: 2.3890
# Epoch [1/15], Step [61/937], Loss: 2.1697
# Epoch [1/15], Step [81/937], Loss: 1.8038
# Epoch [1/15], Step [101/937], Loss: 1.8100
# Epoch [1/15], Step [121/937], Loss: 1.4947
# Epoch [1/15], Step [141/937], Loss: 1.3028
# Epoch [1/15], Step [161/937], Loss: 1.3106
# Epoch [1/15], Step [181/937], Loss: 1.4286
# Epoch [1/15], Step [201/937], Loss: 1.2967
# Epoch [1/15], Step [221/937], Loss: 1.2778
# Epoch [1/15], Step [241/937], Loss: 1.1472
# Epoch [1/15], Step [261/937], Loss: 1.1036
# Epoch [1/15], Step [281/937], Loss: 1.0338
# Epoch [1/15], Step [301/937], Loss: 0.9723
# Epoch [1/15], Step [321/937], Loss: 0.9907
# Epoch [1/15], Step [341/937], Loss: 1.1153
# Epoch [1/15], Step [361/937], Loss: 1.0923
# Epoch [1/15], Step [381/937], Loss: 0.9626
# Epoch [1/15], Step [401/937], Loss: 0.7232
# Epoch [1/15], Step [421/937], Loss: 0.7442
# Epoch [1/15], Step [441/937], Loss: 0.9277
# Epoch [1/15], Step [461/937], Loss: 0.8654
# Epoch [1/15], Step [481/937], Loss: 0.7889
# Epoch [1/15], Step [501/937], Loss: 0.8349
# Epoch [1/15], Step [521/937], Loss: 0.7584
# Epoch [1/15], Step [541/937], Loss: 0.6683
# Epoch [1/15], Step [561/937], Loss: 0.8309
# Epoch [1/15], Step [581/937], Loss: 0.7619
# Epoch [1/15], Step [601/937], Loss: 1.0134
# Epoch [1/15], Step [621/937], Loss: 0.5432
# Epoch [1/15], Step [641/937], Loss: 0.5771
# Epoch [1/15], Step [661/937], Loss: 0.7666
# Epoch [1/15], Step [681/937], Loss: 0.7456
# Epoch [1/15], Step [701/937], Loss: 0.7732
# Epoch [1/15], Step [721/937], Loss: 0.8802
# Epoch [1/15], Step [741/937], Loss: 0.7177
# Epoch [1/15], Step [761/937], Loss: 0.7521
# Epoch [1/15], Step [781/937], Loss: 0.8518
# Epoch [1/15], Step [801/937], Loss: 0.8077
# Epoch [1/15], Step [821/937], Loss: 0.5399
# Epoch [1/15], Step [841/937], Loss: 0.7877
# Epoch [1/15], Step [861/937], Loss: 0.6787
# Epoch [1/15], Step [881/937], Loss: 0.7383
# Epoch [1/15], Step [901/937], Loss: 0.5820
# Epoch [1/15], Step [921/937], Loss: 0.7087
# Epoch [2/15], Step [1/937], Loss: 0.7315
# Epoch [2/15], Step [21/937], Loss: 0.7545
# Epoch [2/15], Step [41/937], Loss: 0.6199
# Epoch [2/15], Step [61/937], Loss: 0.5658
# Epoch [2/15], Step [81/937], Loss: 0.9738
# Epoch [2/15], Step [101/937], Loss: 0.8463
# Epoch [2/15], Step [121/937], Loss: 0.9512
# Epoch [2/15], Step [141/937], Loss: 0.5981
# Epoch [2/15], Step [161/937], Loss: 0.5845
# Epoch [2/15], Step [181/937], Loss: 0.6944
# Epoch [2/15], Step [201/937], Loss: 0.3617
# Epoch [2/15], Step [221/937], Loss: 0.4475
# Epoch [2/15], Step [241/937], Loss: 0.8069
# Epoch [2/15], Step [261/937], Loss: 0.8340
# Epoch [2/15], Step [281/937], Loss: 0.5938
# Epoch [2/15], Step [301/937], Loss: 0.4768
# Epoch [2/15], Step [321/937], Loss: 0.8429
# Epoch [2/15], Step [341/937], Loss: 0.4821
# Epoch [2/15], Step [361/937], Loss: 0.5287
# Epoch [2/15], Step [381/937], Loss: 0.4835
# Epoch [2/15], Step [401/937], Loss: 0.6333
# Epoch [2/15], Step [421/937], Loss: 0.4016
# Epoch [2/15], Step [441/937], Loss: 0.3321
# Epoch [2/15], Step [461/937], Loss: 0.6642
# Epoch [2/15], Step [481/937], Loss: 0.8532
# Epoch [2/15], Step [501/937], Loss: 0.6118
# Epoch [2/15], Step [521/937], Loss: 0.4493
# Epoch [2/15], Step [541/937], Loss: 0.6289
# Epoch [2/15], Step [561/937], Loss: 0.7884
# Epoch [2/15], Step [581/937], Loss: 0.7484
# Epoch [2/15], Step [601/937], Loss: 0.5364
# Epoch [2/15], Step [621/937], Loss: 0.3153
# Epoch [2/15], Step [641/937], Loss: 0.3838
# Epoch [2/15], Step [661/937], Loss: 0.5420
# Epoch [2/15], Step [681/937], Loss: 0.4569
# Epoch [2/15], Step [701/937], Loss: 0.5678
# Epoch [2/15], Step [721/937], Loss: 0.4824
# Epoch [2/15], Step [741/937], Loss: 0.6551
# Epoch [2/15], Step [761/937], Loss: 0.5788
# Epoch [2/15], Step [781/937], Loss: 0.5858
# Epoch [2/15], Step [801/937], Loss: 0.8610
# Epoch [2/15], Step [821/937], Loss: 0.6299
# Epoch [2/15], Step [841/937], Loss: 0.5751
# Epoch [2/15], Step [861/937], Loss: 0.6212
# Epoch [2/15], Step [881/937], Loss: 0.4999
# Epoch [2/15], Step [901/937], Loss: 0.3281
# Epoch [2/15], Step [921/937], Loss: 0.4768
# Epoch [3/15], Step [1/937], Loss: 0.4466
# Epoch [3/15], Step [21/937], Loss: 0.8654
# Epoch [3/15], Step [41/937], Loss: 0.4710
# Epoch [3/15], Step [61/937], Loss: 0.8114
# Epoch [3/15], Step [81/937], Loss: 0.7628
# Epoch [3/15], Step [101/937], Loss: 0.5990
# Epoch [3/15], Step [121/937], Loss: 0.4542
# Epoch [3/15], Step [141/937], Loss: 0.4947
# Epoch [3/15], Step [161/937], Loss: 0.3779
# Epoch [3/15], Step [181/937], Loss: 0.4113
# Epoch [3/15], Step [201/937], Loss: 0.6130
# Epoch [3/15], Step [221/937], Loss: 0.6855
# Epoch [3/15], Step [241/937], Loss: 0.4914
# Epoch [3/15], Step [261/937], Loss: 0.6271
# Epoch [3/15], Step [281/937], Loss: 0.5681
# Epoch [3/15], Step [301/937], Loss: 0.3681
# Epoch [3/15], Step [321/937], Loss: 0.3825
# Epoch [3/15], Step [341/937], Loss: 0.3787
# Epoch [3/15], Step [361/937], Loss: 0.5355
# Epoch [3/15], Step [381/937], Loss: 0.5155
# Epoch [3/15], Step [401/937], Loss: 0.4172
# Epoch [3/15], Step [421/937], Loss: 0.7155
# Epoch [3/15], Step [441/937], Loss: 0.2937
# Epoch [3/15], Step [461/937], Loss: 0.4146
# Epoch [3/15], Step [481/937], Loss: 0.3810
# Epoch [3/15], Step [501/937], Loss: 0.4561
# Epoch [3/15], Step [521/937], Loss: 0.3810
# Epoch [3/15], Step [541/937], Loss: 0.4368
# Epoch [3/15], Step [561/937], Loss: 0.5580
# Epoch [3/15], Step [581/937], Loss: 0.6469
# Epoch [3/15], Step [601/937], Loss: 0.4297
# Epoch [3/15], Step [621/937], Loss: 0.4034
# Epoch [3/15], Step [641/937], Loss: 0.5333
# Epoch [3/15], Step [661/937], Loss: 0.4829
# Epoch [3/15], Step [681/937], Loss: 0.6135
# Epoch [3/15], Step [701/937], Loss: 0.4127
# Epoch [3/15], Step [721/937], Loss: 0.5123
# Epoch [3/15], Step [741/937], Loss: 0.4367
# Epoch [3/15], Step [761/937], Loss: 0.3946
# Epoch [3/15], Step [781/937], Loss: 0.5007
# Epoch [3/15], Step [801/937], Loss: 0.6717
# Epoch [3/15], Step [821/937], Loss: 0.4835
# Epoch [3/15], Step [841/937], Loss: 0.3564
# Epoch [3/15], Step [861/937], Loss: 0.5781
# Epoch [3/15], Step [881/937], Loss: 0.3375
# Epoch [3/15], Step [901/937], Loss: 0.2924
# Epoch [3/15], Step [921/937], Loss: 0.5035
# Epoch [4/15], Step [1/937], Loss: 0.7232
# Epoch [4/15], Step [21/937], Loss: 0.4218
# Epoch [4/15], Step [41/937], Loss: 0.4606
# Epoch [4/15], Step [61/937], Loss: 0.3762
# Epoch [4/15], Step [81/937], Loss: 0.4397
# Epoch [4/15], Step [101/937], Loss: 0.5863
# Epoch [4/15], Step [121/937], Loss: 0.3047
# Epoch [4/15], Step [141/937], Loss: 0.4429
# Epoch [4/15], Step [161/937], Loss: 0.4502
# Epoch [4/15], Step [181/937], Loss: 0.5820
# Epoch [4/15], Step [201/937], Loss: 0.2273
# Epoch [4/15], Step [221/937], Loss: 0.5616
# Epoch [4/15], Step [241/937], Loss: 0.5069
# Epoch [4/15], Step [261/937], Loss: 0.4371
# Epoch [4/15], Step [281/937], Loss: 0.6397
# Epoch [4/15], Step [301/937], Loss: 0.5831
# Epoch [4/15], Step [321/937], Loss: 0.6078
# Epoch [4/15], Step [341/937], Loss: 0.6979
# Epoch [4/15], Step [361/937], Loss: 0.6293
# Epoch [4/15], Step [381/937], Loss: 0.4862
# Epoch [4/15], Step [401/937], Loss: 0.2628
# Epoch [4/15], Step [421/937], Loss: 0.2783
# Epoch [4/15], Step [441/937], Loss: 0.4139
# Epoch [4/15], Step [461/937], Loss: 0.5297
# Epoch [4/15], Step [481/937], Loss: 0.5366
# Epoch [4/15], Step [501/937], Loss: 0.2645
# Epoch [4/15], Step [521/937], Loss: 0.4956
# Epoch [4/15], Step [541/937], Loss: 0.4455
# Epoch [4/15], Step [561/937], Loss: 0.3993
# Epoch [4/15], Step [581/937], Loss: 0.4660
# Epoch [4/15], Step [601/937], Loss: 0.4561
# Epoch [4/15], Step [621/937], Loss: 0.5201
# Epoch [4/15], Step [641/937], Loss: 0.6310
# Epoch [4/15], Step [661/937], Loss: 0.5212
# Epoch [4/15], Step [681/937], Loss: 0.5314
# Epoch [4/15], Step [701/937], Loss: 0.4110
# Epoch [4/15], Step [721/937], Loss: 0.5749
# Epoch [4/15], Step [741/937], Loss: 0.3363
# Epoch [4/15], Step [761/937], Loss: 0.5877
# Epoch [4/15], Step [781/937], Loss: 0.3321
# Epoch [4/15], Step [801/937], Loss: 0.4296
# Epoch [4/15], Step [821/937], Loss: 0.6104
# Epoch [4/15], Step [841/937], Loss: 0.5148
# Epoch [4/15], Step [861/937], Loss: 0.4240
# Epoch [4/15], Step [881/937], Loss: 0.2578
# Epoch [4/15], Step [901/937], Loss: 0.2835
# Epoch [4/15], Step [921/937], Loss: 0.7315
# Epoch [5/15], Step [1/937], Loss: 0.3417
# Epoch [5/15], Step [21/937], Loss: 0.7717
# Epoch [5/15], Step [41/937], Loss: 0.5253
# Epoch [5/15], Step [61/937], Loss: 0.4115
# Epoch [5/15], Step [81/937], Loss: 0.3114
# Epoch [5/15], Step [101/937], Loss: 0.2366
# Epoch [5/15], Step [121/937], Loss: 0.4581
# Epoch [5/15], Step [141/937], Loss: 0.6351
# Epoch [5/15], Step [161/937], Loss: 0.2620
# Epoch [5/15], Step [181/937], Loss: 0.4859
# Epoch [5/15], Step [201/937], Loss: 0.5952
# Epoch [5/15], Step [221/937], Loss: 0.6187
# Epoch [5/15], Step [241/937], Loss: 0.3822
# Epoch [5/15], Step [261/937], Loss: 0.2898
# Epoch [5/15], Step [281/937], Loss: 0.2919
# Epoch [5/15], Step [301/937], Loss: 0.3450
# Epoch [5/15], Step [321/937], Loss: 0.4136
# Epoch [5/15], Step [341/937], Loss: 0.3865
# Epoch [5/15], Step [361/937], Loss: 0.3850
# Epoch [5/15], Step [381/937], Loss: 0.5088
# Epoch [5/15], Step [401/937], Loss: 0.5566
# Epoch [5/15], Step [421/937], Loss: 0.5432
# Epoch [5/15], Step [441/937], Loss: 0.5509
# Epoch [5/15], Step [461/937], Loss: 0.5561
# Epoch [5/15], Step [481/937], Loss: 0.4415
# Epoch [5/15], Step [501/937], Loss: 0.5160
# Epoch [5/15], Step [521/937], Loss: 0.5135
# Epoch [5/15], Step [541/937], Loss: 0.3151
# Epoch [5/15], Step [561/937], Loss: 0.3444
# Epoch [5/15], Step [581/937], Loss: 0.6290
# Epoch [5/15], Step [601/937], Loss: 0.5066
# Epoch [5/15], Step [621/937], Loss: 0.7462
# Epoch [5/15], Step [641/937], Loss: 0.6712
# Epoch [5/15], Step [661/937], Loss: 0.5743
# Epoch [5/15], Step [681/937], Loss: 0.5321
# Epoch [5/15], Step [701/937], Loss: 0.3576
# Epoch [5/15], Step [721/937], Loss: 0.3763
# Epoch [5/15], Step [741/937], Loss: 0.2635
# Epoch [5/15], Step [761/937], Loss: 0.2127
# Epoch [5/15], Step [781/937], Loss: 0.3612
# Epoch [5/15], Step [801/937], Loss: 0.3169
# Epoch [5/15], Step [821/937], Loss: 0.3491
# Epoch [5/15], Step [841/937], Loss: 0.4777
# Epoch [5/15], Step [861/937], Loss: 0.4184
# Epoch [5/15], Step [881/937], Loss: 0.4857
# Epoch [5/15], Step [901/937], Loss: 0.4976
# Epoch [5/15], Step [921/937], Loss: 0.2919
# Epoch [6/15], Step [1/937], Loss: 0.3599
# Epoch [6/15], Step [21/937], Loss: 0.1839
# Epoch [6/15], Step [41/937], Loss: 0.5592
# Epoch [6/15], Step [61/937], Loss: 0.4452
# Epoch [6/15], Step [81/937], Loss: 0.2820
# Epoch [6/15], Step [101/937], Loss: 0.2763
# Epoch [6/15], Step [121/937], Loss: 0.4353
# Epoch [6/15], Step [141/937], Loss: 0.5905
# Epoch [6/15], Step [161/937], Loss: 0.6513
# Epoch [6/15], Step [181/937], Loss: 0.5530
# Epoch [6/15], Step [201/937], Loss: 0.3415
# Epoch [6/15], Step [221/937], Loss: 0.5813
# Epoch [6/15], Step [241/937], Loss: 0.4628
# Epoch [6/15], Step [261/937], Loss: 0.2865
# Epoch [6/15], Step [281/937], Loss: 0.2026
# Epoch [6/15], Step [301/937], Loss: 0.3132
# Epoch [6/15], Step [321/937], Loss: 0.2204
# Epoch [6/15], Step [341/937], Loss: 0.4617
# Epoch [6/15], Step [361/937], Loss: 0.3085
# Epoch [6/15], Step [381/937], Loss: 0.1816
# Epoch [6/15], Step [401/937], Loss: 0.2892
# Epoch [6/15], Step [421/937], Loss: 0.3130
# Epoch [6/15], Step [441/937], Loss: 0.4300
# Epoch [6/15], Step [461/937], Loss: 0.2802
# Epoch [6/15], Step [481/937], Loss: 0.4817
# Epoch [6/15], Step [501/937], Loss: 0.4542
# Epoch [6/15], Step [521/937], Loss: 0.3272
# Epoch [6/15], Step [541/937], Loss: 0.3775
# Epoch [6/15], Step [561/937], Loss: 0.4811
# Epoch [6/15], Step [581/937], Loss: 0.4202
# Epoch [6/15], Step [601/937], Loss: 0.3978
# Epoch [6/15], Step [621/937], Loss: 0.3400
# Epoch [6/15], Step [641/937], Loss: 0.1950
# Epoch [6/15], Step [661/937], Loss: 0.2553
# Epoch [6/15], Step [681/937], Loss: 0.3534
# Epoch [6/15], Step [701/937], Loss: 0.2743
# Epoch [6/15], Step [721/937], Loss: 0.2198
# Epoch [6/15], Step [741/937], Loss: 0.5162
# Epoch [6/15], Step [761/937], Loss: 0.4744
# Epoch [6/15], Step [781/937], Loss: 0.5216
# Epoch [6/15], Step [801/937], Loss: 0.4614
# Epoch [6/15], Step [821/937], Loss: 0.2121
# Epoch [6/15], Step [841/937], Loss: 0.3413
# Epoch [6/15], Step [861/937], Loss: 0.3052
# Epoch [6/15], Step [881/937], Loss: 0.3484
# Epoch [6/15], Step [901/937], Loss: 0.4495
# Epoch [6/15], Step [921/937], Loss: 0.6341
# Epoch [7/15], Step [1/937], Loss: 0.2358
# Epoch [7/15], Step [21/937], Loss: 0.4416
# Epoch [7/15], Step [41/937], Loss: 0.3544
# Epoch [7/15], Step [61/937], Loss: 0.4611
# Epoch [7/15], Step [81/937], Loss: 0.5792
# Epoch [7/15], Step [101/937], Loss: 0.4677
# Epoch [7/15], Step [121/937], Loss: 0.5112
# Epoch [7/15], Step [141/937], Loss: 0.5012
# Epoch [7/15], Step [161/937], Loss: 0.8376
# Epoch [7/15], Step [181/937], Loss: 0.4230
# Epoch [7/15], Step [201/937], Loss: 0.2401
# Epoch [7/15], Step [221/937], Loss: 0.5733
# Epoch [7/15], Step [241/937], Loss: 0.4609
# Epoch [7/15], Step [261/937], Loss: 0.5900
# Epoch [7/15], Step [281/937], Loss: 0.2828
# Epoch [7/15], Step [301/937], Loss: 0.2347
# Epoch [7/15], Step [321/937], Loss: 0.3798
# Epoch [7/15], Step [341/937], Loss: 0.2696
# Epoch [7/15], Step [361/937], Loss: 0.3943
# Epoch [7/15], Step [381/937], Loss: 0.3200
# Epoch [7/15], Step [401/937], Loss: 0.2503
# Epoch [7/15], Step [421/937], Loss: 0.2930
# Epoch [7/15], Step [441/937], Loss: 0.2762
# Epoch [7/15], Step [461/937], Loss: 0.1753
# Epoch [7/15], Step [481/937], Loss: 0.4639
# Epoch [7/15], Step [501/937], Loss: 0.2588
# Epoch [7/15], Step [521/937], Loss: 0.3700
# Epoch [7/15], Step [541/937], Loss: 0.3877
# Epoch [7/15], Step [561/937], Loss: 0.3698
# Epoch [7/15], Step [581/937], Loss: 0.2117
# Epoch [7/15], Step [601/937], Loss: 0.4766
# Epoch [7/15], Step [621/937], Loss: 0.2703
# Epoch [7/15], Step [641/937], Loss: 0.2726
# Epoch [7/15], Step [661/937], Loss: 0.5153
# Epoch [7/15], Step [681/937], Loss: 0.3126
# Epoch [7/15], Step [701/937], Loss: 0.1868
# Epoch [7/15], Step [721/937], Loss: 0.4708
# Epoch [7/15], Step [741/937], Loss: 0.3698
# Epoch [7/15], Step [761/937], Loss: 0.3901
# Epoch [7/15], Step [781/937], Loss: 0.2867
# Epoch [7/15], Step [801/937], Loss: 0.2812
# Epoch [7/15], Step [821/937], Loss: 0.2276
# Epoch [7/15], Step [841/937], Loss: 0.4786
# Epoch [7/15], Step [861/937], Loss: 0.3190
# Epoch [7/15], Step [881/937], Loss: 0.2937
# Epoch [7/15], Step [901/937], Loss: 0.2240
# Epoch [7/15], Step [921/937], Loss: 0.4025
# Epoch [8/15], Step [1/937], Loss: 0.4904
# Epoch [8/15], Step [21/937], Loss: 0.7018
# Epoch [8/15], Step [41/937], Loss: 0.2648
# Epoch [8/15], Step [61/937], Loss: 0.2270
# Epoch [8/15], Step [81/937], Loss: 0.2695
# Epoch [8/15], Step [101/937], Loss: 0.3475
# Epoch [8/15], Step [121/937], Loss: 0.3837
# Epoch [8/15], Step [141/937], Loss: 0.4956
# Epoch [8/15], Step [161/937], Loss: 0.3890
# Epoch [8/15], Step [181/937], Loss: 0.3756
# Epoch [8/15], Step [201/937], Loss: 0.2858
# Epoch [8/15], Step [221/937], Loss: 0.2306
# Epoch [8/15], Step [241/937], Loss: 0.4276
# Epoch [8/15], Step [261/937], Loss: 0.7084
# Epoch [8/15], Step [281/937], Loss: 0.4458
# Epoch [8/15], Step [301/937], Loss: 0.3592
# Epoch [8/15], Step [321/937], Loss: 0.3041
# Epoch [8/15], Step [341/937], Loss: 0.3505
# Epoch [8/15], Step [361/937], Loss: 0.4131
# Epoch [8/15], Step [381/937], Loss: 0.3279
# Epoch [8/15], Step [401/937], Loss: 0.6227
# Epoch [8/15], Step [421/937], Loss: 0.5867
# Epoch [8/15], Step [441/937], Loss: 0.3745
# Epoch [8/15], Step [461/937], Loss: 0.2758
# Epoch [8/15], Step [481/937], Loss: 0.3274
# Epoch [8/15], Step [501/937], Loss: 0.5845
# Epoch [8/15], Step [521/937], Loss: 0.7192
# Epoch [8/15], Step [541/937], Loss: 0.2896
# Epoch [8/15], Step [561/937], Loss: 0.2845
# Epoch [8/15], Step [581/937], Loss: 0.2515
# Epoch [8/15], Step [601/937], Loss: 0.4453
# Epoch [8/15], Step [621/937], Loss: 0.2916
# Epoch [8/15], Step [641/937], Loss: 0.4488
# Epoch [8/15], Step [661/937], Loss: 0.2649
# Epoch [8/15], Step [681/937], Loss: 0.4301
# Epoch [8/15], Step [701/937], Loss: 0.2887
# Epoch [8/15], Step [721/937], Loss: 0.3841
# Epoch [8/15], Step [741/937], Loss: 0.6589
# Epoch [8/15], Step [761/937], Loss: 0.5092
# Epoch [8/15], Step [781/937], Loss: 0.4339
# Epoch [8/15], Step [801/937], Loss: 0.4797
# Epoch [8/15], Step [821/937], Loss: 0.2894
# Epoch [8/15], Step [841/937], Loss: 0.3992
# Epoch [8/15], Step [861/937], Loss: 0.3460
# Epoch [8/15], Step [881/937], Loss: 0.4975
# Epoch [8/15], Step [901/937], Loss: 0.5662
# Epoch [8/15], Step [921/937], Loss: 0.2378
# Epoch [9/15], Step [1/937], Loss: 0.1127
# Epoch [9/15], Step [21/937], Loss: 0.4817
# Epoch [9/15], Step [41/937], Loss: 0.5251
# Epoch [9/15], Step [61/937], Loss: 0.4228
# Epoch [9/15], Step [81/937], Loss: 0.1258
# Epoch [9/15], Step [101/937], Loss: 0.2863
# Epoch [9/15], Step [121/937], Loss: 0.4272
# Epoch [9/15], Step [141/937], Loss: 0.3052
# Epoch [9/15], Step [161/937], Loss: 0.4755
# Epoch [9/15], Step [181/937], Loss: 0.3447
# Epoch [9/15], Step [201/937], Loss: 0.3259
# Epoch [9/15], Step [221/937], Loss: 0.3111
# Epoch [9/15], Step [241/937], Loss: 0.3122
# Epoch [9/15], Step [261/937], Loss: 0.3579
# Epoch [9/15], Step [281/937], Loss: 0.4079
# Epoch [9/15], Step [301/937], Loss: 0.1829
# Epoch [9/15], Step [321/937], Loss: 0.3422
# Epoch [9/15], Step [341/937], Loss: 0.4335
# Epoch [9/15], Step [361/937], Loss: 0.2214
# Epoch [9/15], Step [381/937], Loss: 0.1907
# Epoch [9/15], Step [401/937], Loss: 0.3244
# Epoch [9/15], Step [421/937], Loss: 0.4787
# Epoch [9/15], Step [441/937], Loss: 0.5240
# Epoch [9/15], Step [461/937], Loss: 0.1556
# Epoch [9/15], Step [481/937], Loss: 0.4168
# Epoch [9/15], Step [501/937], Loss: 0.5329
# Epoch [9/15], Step [521/937], Loss: 0.3130
# Epoch [9/15], Step [541/937], Loss: 0.5436
# Epoch [9/15], Step [561/937], Loss: 0.3704
# Epoch [9/15], Step [581/937], Loss: 0.3869
# Epoch [9/15], Step [601/937], Loss: 0.4599
# Epoch [9/15], Step [621/937], Loss: 0.3019
# Epoch [9/15], Step [641/937], Loss: 0.2556
# Epoch [9/15], Step [661/937], Loss: 0.3265
# Epoch [9/15], Step [681/937], Loss: 0.3525
# Epoch [9/15], Step [701/937], Loss: 0.3025
# Epoch [9/15], Step [721/937], Loss: 0.3053
# Epoch [9/15], Step [741/937], Loss: 0.4768
# Epoch [9/15], Step [761/937], Loss: 0.2881
# Epoch [9/15], Step [781/937], Loss: 0.1529
# Epoch [9/15], Step [801/937], Loss: 0.2586
# Epoch [9/15], Step [821/937], Loss: 0.1822
# Epoch [9/15], Step [841/937], Loss: 0.4259
# Epoch [9/15], Step [861/937], Loss: 0.3133
# Epoch [9/15], Step [881/937], Loss: 0.3054
# Epoch [9/15], Step [901/937], Loss: 0.5536
# Epoch [9/15], Step [921/937], Loss: 0.3543
# Epoch [10/15], Step [1/937], Loss: 0.1609
# Epoch [10/15], Step [21/937], Loss: 0.3381
# Epoch [10/15], Step [41/937], Loss: 0.2151
# Epoch [10/15], Step [61/937], Loss: 0.1868
# Epoch [10/15], Step [81/937], Loss: 0.4791
# Epoch [10/15], Step [101/937], Loss: 0.2824
# Epoch [10/15], Step [121/937], Loss: 0.5506
# Epoch [10/15], Step [141/937], Loss: 0.2211
# Epoch [10/15], Step [161/937], Loss: 0.3018
# Epoch [10/15], Step [181/937], Loss: 0.5295
# Epoch [10/15], Step [201/937], Loss: 0.1647
# Epoch [10/15], Step [221/937], Loss: 0.0816
# Epoch [10/15], Step [241/937], Loss: 0.2869
# Epoch [10/15], Step [261/937], Loss: 0.0944
# Epoch [10/15], Step [281/937], Loss: 0.2357
# Epoch [10/15], Step [301/937], Loss: 0.2425
# Epoch [10/15], Step [321/937], Loss: 0.1780
# Epoch [10/15], Step [341/937], Loss: 0.2798
# Epoch [10/15], Step [361/937], Loss: 0.5636
# Epoch [10/15], Step [381/937], Loss: 0.1447
# Epoch [10/15], Step [401/937], Loss: 0.4429
# Epoch [10/15], Step [421/937], Loss: 0.5070
# Epoch [10/15], Step [441/937], Loss: 0.2510
# Epoch [10/15], Step [461/937], Loss: 0.3910
# Epoch [10/15], Step [481/937], Loss: 0.1293
# Epoch [10/15], Step [501/937], Loss: 0.3083
# Epoch [10/15], Step [521/937], Loss: 0.1446
# Epoch [10/15], Step [541/937], Loss: 0.2678
# Epoch [10/15], Step [561/937], Loss: 0.2991
# Epoch [10/15], Step [581/937], Loss: 0.2489
# Epoch [10/15], Step [601/937], Loss: 0.3143
# Epoch [10/15], Step [621/937], Loss: 0.3862
# Epoch [10/15], Step [641/937], Loss: 0.1889
# Epoch [10/15], Step [661/937], Loss: 0.2477
# Epoch [10/15], Step [681/937], Loss: 0.1920
# Epoch [10/15], Step [701/937], Loss: 0.4181
# Epoch [10/15], Step [721/937], Loss: 0.2540
# Epoch [10/15], Step [741/937], Loss: 0.2116
# Epoch [10/15], Step [761/937], Loss: 0.2950
# Epoch [10/15], Step [781/937], Loss: 0.5149
# Epoch [10/15], Step [801/937], Loss: 0.3292
# Epoch [10/15], Step [821/937], Loss: 0.1768
# Epoch [10/15], Step [841/937], Loss: 0.2451
# Epoch [10/15], Step [861/937], Loss: 0.3001
# Epoch [10/15], Step [881/937], Loss: 0.2332
# Epoch [10/15], Step [901/937], Loss: 0.2205
# Epoch [10/15], Step [921/937], Loss: 0.3985
# Epoch [11/15], Step [1/937], Loss: 0.3835
# Epoch [11/15], Step [21/937], Loss: 0.4380
# Epoch [11/15], Step [41/937], Loss: 0.4447
# Epoch [11/15], Step [61/937], Loss: 0.2693
# Epoch [11/15], Step [81/937], Loss: 0.1811
# Epoch [11/15], Step [101/937], Loss: 0.1616
# Epoch [11/15], Step [121/937], Loss: 0.1420
# Epoch [11/15], Step [141/937], Loss: 0.3764
# Epoch [11/15], Step [161/937], Loss: 0.6807
# Epoch [11/15], Step [181/937], Loss: 0.4011
# Epoch [11/15], Step [201/937], Loss: 0.1876
# Epoch [11/15], Step [221/937], Loss: 0.5525
# Epoch [11/15], Step [241/937], Loss: 0.3659
# Epoch [11/15], Step [261/937], Loss: 0.1056
# Epoch [11/15], Step [281/937], Loss: 0.4049
# Epoch [11/15], Step [301/937], Loss: 0.2329
# Epoch [11/15], Step [321/937], Loss: 0.1358
# Epoch [11/15], Step [341/937], Loss: 0.3594
# Epoch [11/15], Step [361/937], Loss: 0.4072
# Epoch [11/15], Step [381/937], Loss: 0.2271
# Epoch [11/15], Step [401/937], Loss: 0.2992
# Epoch [11/15], Step [421/937], Loss: 0.3887
# Epoch [11/15], Step [441/937], Loss: 0.3608
# Epoch [11/15], Step [461/937], Loss: 0.1364
# Epoch [11/15], Step [481/937], Loss: 0.3210
# Epoch [11/15], Step [501/937], Loss: 0.2817
# Epoch [11/15], Step [521/937], Loss: 0.4765
# Epoch [11/15], Step [541/937], Loss: 0.3644
# Epoch [11/15], Step [561/937], Loss: 0.4948
# Epoch [11/15], Step [581/937], Loss: 0.2370
# Epoch [11/15], Step [601/937], Loss: 0.3859
# Epoch [11/15], Step [621/937], Loss: 0.2121
# Epoch [11/15], Step [641/937], Loss: 0.2899
# Epoch [11/15], Step [661/937], Loss: 0.1909
# Epoch [11/15], Step [681/937], Loss: 0.3148
# Epoch [11/15], Step [701/937], Loss: 0.2450
# Epoch [11/15], Step [721/937], Loss: 0.2905
# Epoch [11/15], Step [741/937], Loss: 0.2956
# Epoch [11/15], Step [761/937], Loss: 0.1317
# Epoch [11/15], Step [781/937], Loss: 0.1948
# Epoch [11/15], Step [801/937], Loss: 0.2878
# Epoch [11/15], Step [821/937], Loss: 0.2039
# Epoch [11/15], Step [841/937], Loss: 0.3443
# Epoch [11/15], Step [861/937], Loss: 0.4092
# Epoch [11/15], Step [881/937], Loss: 0.3134
# Epoch [11/15], Step [901/937], Loss: 0.4693
# Epoch [11/15], Step [921/937], Loss: 0.1227
# Epoch [12/15], Step [1/937], Loss: 0.1191
# Epoch [12/15], Step [21/937], Loss: 0.1528
# Epoch [12/15], Step [41/937], Loss: 0.4878
# Epoch [12/15], Step [61/937], Loss: 0.2391
# Epoch [12/15], Step [81/937], Loss: 0.2925
# Epoch [12/15], Step [101/937], Loss: 0.2204
# Epoch [12/15], Step [121/937], Loss: 0.4027
# Epoch [12/15], Step [141/937], Loss: 0.4584
# Epoch [12/15], Step [161/937], Loss: 0.3431
# Epoch [12/15], Step [181/937], Loss: 0.3237
# Epoch [12/15], Step [201/937], Loss: 0.6457
# Epoch [12/15], Step [221/937], Loss: 0.5623
# Epoch [12/15], Step [241/937], Loss: 0.3678
# Epoch [12/15], Step [261/937], Loss: 0.2867
# Epoch [12/15], Step [281/937], Loss: 0.2466
# Epoch [12/15], Step [301/937], Loss: 0.2915
# Epoch [12/15], Step [321/937], Loss: 0.2645
# Epoch [12/15], Step [341/937], Loss: 0.3101
# Epoch [12/15], Step [361/937], Loss: 0.3505
# Epoch [12/15], Step [381/937], Loss: 0.1815
# Epoch [12/15], Step [401/937], Loss: 0.1328
# Epoch [12/15], Step [421/937], Loss: 0.1953
# Epoch [12/15], Step [441/937], Loss: 0.3329
# Epoch [12/15], Step [461/937], Loss: 0.1684
# Epoch [12/15], Step [481/937], Loss: 0.2436
# Epoch [12/15], Step [501/937], Loss: 0.2240
# Epoch [12/15], Step [521/937], Loss: 0.2129
# Epoch [12/15], Step [541/937], Loss: 0.4625
# Epoch [12/15], Step [561/937], Loss: 0.2180
# Epoch [12/15], Step [581/937], Loss: 0.4322
# Epoch [12/15], Step [601/937], Loss: 0.1533
# Epoch [12/15], Step [621/937], Loss: 0.2015
# Epoch [12/15], Step [641/937], Loss: 0.1629
# Epoch [12/15], Step [661/937], Loss: 0.3957
# Epoch [12/15], Step [681/937], Loss: 0.2093
# Epoch [12/15], Step [701/937], Loss: 0.2480
# Epoch [12/15], Step [721/937], Loss: 0.4612
# Epoch [12/15], Step [741/937], Loss: 0.2368
# Epoch [12/15], Step [761/937], Loss: 0.1607
# Epoch [12/15], Step [781/937], Loss: 0.3444
# Epoch [12/15], Step [801/937], Loss: 0.2529
# Epoch [12/15], Step [821/937], Loss: 0.1964
# Epoch [12/15], Step [841/937], Loss: 0.2227
# Epoch [12/15], Step [861/937], Loss: 0.4388
# Epoch [12/15], Step [881/937], Loss: 0.2314
# Epoch [12/15], Step [901/937], Loss: 0.3163
# Epoch [12/15], Step [921/937], Loss: 0.2245
# Epoch [13/15], Step [1/937], Loss: 0.2092
# Epoch [13/15], Step [21/937], Loss: 0.3696
# Epoch [13/15], Step [41/937], Loss: 0.4278
# Epoch [13/15], Step [61/937], Loss: 0.2984
# Epoch [13/15], Step [81/937], Loss: 0.2987
# Epoch [13/15], Step [101/937], Loss: 0.2115
# Epoch [13/15], Step [121/937], Loss: 0.3206
# Epoch [13/15], Step [141/937], Loss: 0.0850
# Epoch [13/15], Step [161/937], Loss: 0.3236
# Epoch [13/15], Step [181/937], Loss: 0.2504
# Epoch [13/15], Step [201/937], Loss: 0.4226
# Epoch [13/15], Step [221/937], Loss: 0.1802
# Epoch [13/15], Step [241/937], Loss: 0.2105
# Epoch [13/15], Step [261/937], Loss: 0.2917
# Epoch [13/15], Step [281/937], Loss: 0.3325
# Epoch [13/15], Step [301/937], Loss: 0.1714
# Epoch [13/15], Step [321/937], Loss: 0.2136
# Epoch [13/15], Step [341/937], Loss: 0.1639
# Epoch [13/15], Step [361/937], Loss: 0.1603
# Epoch [13/15], Step [381/937], Loss: 0.1922
# Epoch [13/15], Step [401/937], Loss: 0.2205
# Epoch [13/15], Step [421/937], Loss: 0.3243
# Epoch [13/15], Step [441/937], Loss: 0.1532
# Epoch [13/15], Step [461/937], Loss: 0.5647
# Epoch [13/15], Step [481/937], Loss: 0.2914
# Epoch [13/15], Step [501/937], Loss: 0.4544
# Epoch [13/15], Step [521/937], Loss: 0.2756
# Epoch [13/15], Step [541/937], Loss: 0.1426
# Epoch [13/15], Step [561/937], Loss: 0.5806
# Epoch [13/15], Step [581/937], Loss: 0.3366
# Epoch [13/15], Step [601/937], Loss: 0.1464
# Epoch [13/15], Step [621/937], Loss: 0.3028
# Epoch [13/15], Step [641/937], Loss: 0.2982
# Epoch [13/15], Step [661/937], Loss: 0.1715
# Epoch [13/15], Step [681/937], Loss: 0.1951
# Epoch [13/15], Step [701/937], Loss: 0.3530
# Epoch [13/15], Step [721/937], Loss: 0.3460
# Epoch [13/15], Step [741/937], Loss: 0.1505
# Epoch [13/15], Step [761/937], Loss: 0.2296
# Epoch [13/15], Step [781/937], Loss: 0.1647
# Epoch [13/15], Step [801/937], Loss: 0.4739
# Epoch [13/15], Step [821/937], Loss: 0.1164
# Epoch [13/15], Step [841/937], Loss: 0.6376
# Epoch [13/15], Step [861/937], Loss: 0.3525
# Epoch [13/15], Step [881/937], Loss: 0.2833
# Epoch [13/15], Step [901/937], Loss: 0.3891
# Epoch [13/15], Step [921/937], Loss: 0.3280
# Epoch [14/15], Step [1/937], Loss: 0.1696
# Epoch [14/15], Step [21/937], Loss: 0.2472
# Epoch [14/15], Step [41/937], Loss: 0.3568
# Epoch [14/15], Step [61/937], Loss: 0.2378
# Epoch [14/15], Step [81/937], Loss: 0.1802
# Epoch [14/15], Step [101/937], Loss: 0.2872
# Epoch [14/15], Step [121/937], Loss: 0.2105
# Epoch [14/15], Step [141/937], Loss: 0.2136
# Epoch [14/15], Step [161/937], Loss: 0.3631
# Epoch [14/15], Step [181/937], Loss: 0.2889
# Epoch [14/15], Step [201/937], Loss: 0.2415
# Epoch [14/15], Step [221/937], Loss: 0.3191
# Epoch [14/15], Step [241/937], Loss: 0.1723
# Epoch [14/15], Step [261/937], Loss: 0.5318
# Epoch [14/15], Step [281/937], Loss: 0.2227
# Epoch [14/15], Step [301/937], Loss: 0.2093
# Epoch [14/15], Step [321/937], Loss: 0.3462
# Epoch [14/15], Step [341/937], Loss: 0.2480
# Epoch [14/15], Step [361/937], Loss: 0.2173
# Epoch [14/15], Step [381/937], Loss: 0.3106
# Epoch [14/15], Step [401/937], Loss: 0.2571
# Epoch [14/15], Step [421/937], Loss: 0.2702
# Epoch [14/15], Step [441/937], Loss: 0.5326
# Epoch [14/15], Step [461/937], Loss: 0.1456
# Epoch [14/15], Step [481/937], Loss: 0.1618
# Epoch [14/15], Step [501/937], Loss: 0.2757
# Epoch [14/15], Step [521/937], Loss: 0.1781
# Epoch [14/15], Step [541/937], Loss: 0.1300
# Epoch [14/15], Step [561/937], Loss: 0.2223
# Epoch [14/15], Step [581/937], Loss: 0.1221
# Epoch [14/15], Step [601/937], Loss: 0.1951
# Epoch [14/15], Step [621/937], Loss: 0.1222
# Epoch [14/15], Step [641/937], Loss: 0.1984
# Epoch [14/15], Step [661/937], Loss: 0.6633
# Epoch [14/15], Step [681/937], Loss: 0.3859
# Epoch [14/15], Step [701/937], Loss: 0.2792
# Epoch [14/15], Step [721/937], Loss: 0.2004
# Epoch [14/15], Step [741/937], Loss: 0.2382
# Epoch [14/15], Step [761/937], Loss: 0.2174
# Epoch [14/15], Step [781/937], Loss: 0.2204
# Epoch [14/15], Step [801/937], Loss: 0.1737
# Epoch [14/15], Step [821/937], Loss: 0.4425
# Epoch [14/15], Step [841/937], Loss: 0.1544
# Epoch [14/15], Step [861/937], Loss: 0.4485
# Epoch [14/15], Step [881/937], Loss: 0.4328
# Epoch [14/15], Step [901/937], Loss: 0.3628
# Epoch [14/15], Step [921/937], Loss: 0.2713
# Epoch [15/15], Step [1/937], Loss: 0.1690
# Epoch [15/15], Step [21/937], Loss: 0.0745
# Epoch [15/15], Step [41/937], Loss: 0.1505
# Epoch [15/15], Step [61/937], Loss: 0.2971
# Epoch [15/15], Step [81/937], Loss: 0.1501
# Epoch [15/15], Step [101/937], Loss: 0.2498
# Epoch [15/15], Step [121/937], Loss: 0.2552
# Epoch [15/15], Step [141/937], Loss: 0.1732
# Epoch [15/15], Step [161/937], Loss: 0.2388
# Epoch [15/15], Step [181/937], Loss: 0.1945
# Epoch [15/15], Step [201/937], Loss: 0.5691
# Epoch [15/15], Step [221/937], Loss: 0.3240
# Epoch [15/15], Step [241/937], Loss: 0.2005
# Epoch [15/15], Step [261/937], Loss: 0.1179
# Epoch [15/15], Step [281/937], Loss: 0.2851
# Epoch [15/15], Step [301/937], Loss: 0.3293
# Epoch [15/15], Step [321/937], Loss: 0.3239
# Epoch [15/15], Step [341/937], Loss: 0.4124
# Epoch [15/15], Step [361/937], Loss: 0.2646
# Epoch [15/15], Step [381/937], Loss: 0.1445
# Epoch [15/15], Step [401/937], Loss: 0.4426
# Epoch [15/15], Step [421/937], Loss: 0.5949
# Epoch [15/15], Step [441/937], Loss: 0.2948
# Epoch [15/15], Step [461/937], Loss: 0.2210
# Epoch [15/15], Step [481/937], Loss: 0.4336
# Epoch [15/15], Step [501/937], Loss: 0.0964
# Epoch [15/15], Step [521/937], Loss: 0.3426
# Epoch [15/15], Step [541/937], Loss: 0.1201
# Epoch [15/15], Step [561/937], Loss: 0.4151
# Epoch [15/15], Step [581/937], Loss: 0.3422
# Epoch [15/15], Step [601/937], Loss: 0.4678
# Epoch [15/15], Step [621/937], Loss: 0.3879
# Epoch [15/15], Step [641/937], Loss: 0.1153
# Epoch [15/15], Step [661/937], Loss: 0.3546
# Epoch [15/15], Step [681/937], Loss: 0.2788
# Epoch [15/15], Step [701/937], Loss: 0.4609
# Epoch [15/15], Step [721/937], Loss: 0.3323
# Epoch [15/15], Step [741/937], Loss: 0.1129
# Epoch [15/15], Step [761/937], Loss: 0.1254
# Epoch [15/15], Step [781/937], Loss: 0.6615
# Epoch [15/15], Step [801/937], Loss: 0.2225
# Epoch [15/15], Step [821/937], Loss: 0.3976
# Epoch [15/15], Step [841/937], Loss: 0.2084
# Epoch [15/15], Step [861/937], Loss: 0.3425
# Epoch [15/15], Step [881/937], Loss: 0.2853
# Epoch [15/15], Step [901/937], Loss: 0.2710
# Epoch [15/15], Step [921/937], Loss: 0.2241

# %%
p=len(test_dataset)
test_batches=p/batch_size

loader = torch.utils.data.DataLoader(dataset=test_dataset,batch_size = p ,shuffle=True)
dataiter = iter(loader)
data = next(dataiter)
X,y = data

X=X.numpy()
y=y.numpy()
# Flatten the images
image_vector_size = 28*28
X = X.reshape(X.shape[0], image_vector_size)
y_one_hot=convert_to_onehot(y,num_classes)
y_hat,out_cache=forward_propagation(X,trained_parameters)

test_accuracy=find_accuracy(y_one_hot,y_hat)
test_cost=compute_cost(y_hat,y_one_hot.T)

# %%
import seaborn as sn
from sklearn.metrics import confusion_matrix
k = np.argmax(y_hat,axis=0)
cm=confusion_matrix(k, y)
plt.figure(figsize=(8,8))
sn.heatmap(confusion_matrix(k, y),annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('truth')
# Out:
# Text(51.0, 0.5, 'truth')

# %%
plt.plot(train_costs)
plt.xlabel('train loss')
plt.ylabel('number of iterations')
plt.title('Train loss with Tanh activation and learning rate 0.01')
plt.show()

# %%
plt.plot(train_acc)
plt.xlabel('train accuracy')
plt.ylabel('number of iterations')
plt.title('Train accuracy with Tanh activation and learning rate 0.01')
plt.show()

# %%
m=len(train_dataset)
train_batches=m/batch_size
# test_costs=[]
# test_accuracy=[]
# for i in range(int(test_batches)):
loader = torch.utils.data.DataLoader(dataset=train_dataset,batch_size = m ,shuffle=True)
dataiter = iter(loader)
data = next(dataiter)
X_train,y_train = data

X_train=X_train.numpy()
y_train=y_train.numpy()
# Flatten the images
image_vector_size = 28*28
X_train = X_train.reshape(X_train.shape[0], image_vector_size)
y_train_one_hot=convert_to_onehot(y_train,num_classes)
y_train_hat,out_train_cache=forward_propagation(X_train,trained_parameters)
#     test_costs.append(compute_cost(y_hat,y_one_hot.T))
#     test_accuracy.append(find_accuracy(y_one_hot,y_hat))
train_accuracy_final=find_accuracy(y_train_one_hot,y_train_hat)
train_cost_final=compute_cost(y_train_hat,y_train_one_hot.T)

# %%
print(train_accuracy_final)
# Out:
# 0.9588333333333333

# %%
print(train_acc[-1])
# Out:
# 0.96875

# %%
print(test_accuracy)
# Out:
# 0.9549
