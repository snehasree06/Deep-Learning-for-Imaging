# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn 
import torchvision
import torchvision.transforms as transforms

# %%
print(torch.__version__)
# Out:
# 1.13.0.dev20220624

# %%
input_size = 784 # 28x28
hidden_layer1= 500 
hidden_layer2=250
hidden_layer3=100
num_classes = 10
num_epochs = 15
batch_size = 64
learning_rate = 0.01

# %%
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(),  download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

# %%
def convert_to_onehot(labels,num_classes):
    output = np.eye(num_classes)[np.array(labels).reshape(-1)]
    return output.reshape(list(np.shape(labels))+[num_classes])

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

def relu(x):
    return np.maximum(0, x)

def softmax(x):
    return np.exp(x)/sum(np.exp(x))

# %%
def sigmoid_derivative(x):
    return sigmoid(x) * (1- sigmoid(x))

def relu_derivative(x):
    return x>0

def softmax_derivative(x):

    return softmax(x)*(1-softmax(x))

# %%
def init_weights(No,Ni):
    M=np.sqrt(6/(Ni+No))
    weights=np.asarray(np.random.uniform(-M, M, (No, Ni)), dtype=np.float64)
    biases  = np.zeros((No,1))
    return weights,biases

# %%
def initialize_parameters(layers_dims):
    w1,b1=init_weights(layers_dims[1],layers_dims[0])
    w2,b2=init_weights(layers_dims[2],layers_dims[1])
    w3,b3=init_weights(layers_dims[3],layers_dims[2])
    w4,b4=init_weights(layers_dims[4],layers_dims[3])
    parameters={
    "w1":w1,
    "w2":w2,
    "w3":w3,
    "w4":w4,
    "b1":b1,
    "b2":b2,
    "b3":b3,
    "b4":b4
    }
    return parameters

# %%
def forward_propagation(X,parameters):
    w1=parameters['w1']
    b1=parameters['b1']
    w2=parameters['w2']
    b2=parameters['b2']
    w3=parameters['w3']
    b3=parameters['b3']
    w4=parameters['w4']
    b4=parameters['b4']
    Z1=np.dot(w1,X.T)+b1
    A1=relu(Z1)
    Z2 = np.dot(w2,A1) + b2
    A2=relu(Z2)
    Z3 = np.dot(w3,A2) + b3
    A3=relu(Z3)
    Z4=np.dot(w4,A3)+b4
    A4=softmax(Z4)
    cache = {
        "Z1" : Z1,
        "Z2" : Z2,
        "Z3" : Z3,
        "Z4" : Z4,
        "A1" : A1,
        "A2" : A2,
        "A3" : A3,
        "A4" : A4,
        "w1" : w1,
        "b1" : b1,
        "w2" : w2,
        "b2" : b2,
        "w3" : w3,
        "b3" : b3,
        "w4" : w4,
        "b4" : b4  
    }
    return A4,cache

# %%
def compute_cost(A, Y):    
    #A is predicted
    #Y is actual
    m = Y.shape[1] 
    logprobs = np.multiply(-np.log(A),Y) + np.multiply(-np.log(1 - A), 1 - Y)
    cost = 1./m * np.nansum(logprobs)
    return cost

# %%
def backward_propagation(X, Y, cache):
    m = X.shape[1]
    A4=cache['A4']
    A3=cache['A3']
    A2=cache['A2']
    A1=cache['A1']
    Z3=cache['Z3']
    Z4=cache['Z4']
    Z2=cache['Z2']
    Z1=cache['Z1']
    w1=cache['w1']
    b1=cache['b1']
    w2=cache['w2']
    b2=cache['b2']
    w3=cache['w3']
    b3=cache['b3']
    w4=cache['w4']
    b4=cache['b4']

    dZ4 = A4 - Y
    dW4 = 1./m * np.dot(dZ4, A3.T)
    db4 = 1./m * np.sum(dZ4, axis=1, keepdims = True)
    
    dA3 = np.dot(w4.T, dZ4)
    dZ3 = np.multiply(dA3, np.int64(A3 > 0))
    dW3 = 1./m * np.dot(dZ3, A2.T)
    db3 = 1./m * np.sum(dZ3, axis=1, keepdims = True)
    
    dA2 = np.dot(w3.T, dZ3)
    dZ2 = np.multiply(dA2, np.int64(A2 > 0))
    dW2 = 1./m * np.dot(dZ2, A1.T)
    db2 = 1./m * np.sum(dZ2, axis=1, keepdims = True)

    dA1 = np.dot(w2.T, dZ2)
    dZ1 = np.multiply(dA1, np.int64(A1 > 0))
    dW1 = 1./m * np.dot(dZ1, X)
    db1 = 1./m * np.sum(dZ1, axis=1, keepdims = True)

    
    gradients = {"dZ4": dZ4, "dW4": dW4, "db4": db4,
                 "dA3": dA3, "dZ3": dZ3, "dW3": dW3, "db3": db3,
                 "dA2": dA2, "dZ2": dZ2, "dW2": dW2, "db2": db2,
                 "dA1": dA1, "dZ1": dZ1, "dW1": dW1, "db1": db1}
    
    return gradients

# %%
def update_parameter(parameters,gradients,learning_rate):
    w1=parameters['w1']
    b1=parameters['b1']
    w2=parameters['w2']
    b2=parameters['b2']
    w3=parameters['w3']
    b3=parameters['b3']
    w4=parameters['w4']
    b4=parameters['b4']
    dW1=gradients['dW1']
    db1=gradients['db1']
    dW2=gradients['dW2']
    db2=gradients['db2']
    dW3=gradients['dW3']
    db3=gradients['db3']
    dW4=gradients['dW4']
    db4=gradients['db4']
    w1 = w1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    w2 = w2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2
    w3 = w3 - learning_rate * dW3
    b3 = b3 - learning_rate * db3
    w4 = w4 - learning_rate * dW4
    b4 = b4 - learning_rate * db4
    
    updated_parameters={
    "w1":w1,
    "w2":w2,
    "w3":w3,
    "w4":w4,
    "b1":b1,
    "b2":b2,
    "b3":b3,
    "b4":b4
    }
    return updated_parameters

# %%
def find_accuracy(y_actual,y_pred):
    accuracy = np.count_nonzero(np.argmax(y_pred,axis=0)==np.argmax(y_actual,axis=1))/y_actual.shape[0]
    return accuracy

# %%
def predict(X,Y,parameters):
    y_pred,cache=forward_propagation(X,parameters)
    return y_pred

# %%
def model1(dataset,layers_dims,num_epochs):
    m=len(dataset)
    num_batches=m/batch_size
    parameters=initialize_parameters(layers_dims)
    costs=[]
    acc=[]
    for epoch in range(num_epochs):
        for i in range(int(num_batches)):
            # Data loader
            loader = torch.utils.data.DataLoader(dataset=dataset,batch_size = batch_size ,shuffle=True)
            dataiter = iter(loader)
            data = next(dataiter)
            X,y = data
            X=X.numpy()
            y=y.numpy()
            # Flatten the images
            image_vector_size = 28*28
            X = X.reshape(X.shape[0], image_vector_size)
            y_one_hot=convert_to_onehot(y,num_classes)
            y_pred,cache=forward_propagation(X,parameters)
            cost=compute_cost(y_pred,y_one_hot.T)
            gradients=backward_propagation(X,y_one_hot.T,cache)
            parameters=update_parameter(parameters,gradients,learning_rate)
            if i%20==0:
                print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{int(num_batches)}], Loss: {cost.item():.4f}')
                costs.append(cost)
                acc.append(find_accuracy(y_one_hot,y_pred))
    return acc,costs,parameters

# %%
layers_dims=[784,500,250,100,10]
train_acc,train_costs,trained_parameters=model1(train_dataset,layers_dims,15)
# Out:
# Epoch [1/15], Step [1/937], Loss: 3.3070
# Epoch [1/15], Step [21/937], Loss: 3.3930
# Epoch [1/15], Step [41/937], Loss: 3.3383
# Epoch [1/15], Step [61/937], Loss: 3.2674
# Epoch [1/15], Step [81/937], Loss: 3.2791
# Epoch [1/15], Step [101/937], Loss: 3.2833
# Epoch [1/15], Step [121/937], Loss: 3.2853
# Epoch [1/15], Step [141/937], Loss: 3.2335
# Epoch [1/15], Step [161/937], Loss: 3.2185
# Epoch [1/15], Step [181/937], Loss: 3.2498
# Epoch [1/15], Step [201/937], Loss: 3.2284
# Epoch [1/15], Step [221/937], Loss: 3.2267
# Epoch [1/15], Step [241/937], Loss: 3.2392
# Epoch [1/15], Step [261/937], Loss: 3.2338
# Epoch [1/15], Step [281/937], Loss: 3.1564
# Epoch [1/15], Step [301/937], Loss: 3.1907
# Epoch [1/15], Step [321/937], Loss: 3.1629
# Epoch [1/15], Step [341/937], Loss: 3.1579
# Epoch [1/15], Step [361/937], Loss: 3.1560
# Epoch [1/15], Step [381/937], Loss: 3.1555
# Epoch [1/15], Step [401/937], Loss: 3.1542
# Epoch [1/15], Step [421/937], Loss: 3.1088
# Epoch [1/15], Step [441/937], Loss: 3.1181
# Epoch [1/15], Step [461/937], Loss: 3.1408
# Epoch [1/15], Step [481/937], Loss: 3.0856
# Epoch [1/15], Step [501/937], Loss: 3.0757
# Epoch [1/15], Step [521/937], Loss: 3.1340
# Epoch [1/15], Step [541/937], Loss: 3.0745
# Epoch [1/15], Step [561/937], Loss: 3.0650
# Epoch [1/15], Step [581/937], Loss: 3.0187
# Epoch [1/15], Step [601/937], Loss: 3.1043
# Epoch [1/15], Step [621/937], Loss: 3.0412
# Epoch [1/15], Step [641/937], Loss: 2.9934
# Epoch [1/15], Step [661/937], Loss: 2.9708
# Epoch [1/15], Step [681/937], Loss: 3.0188
# Epoch [1/15], Step [701/937], Loss: 3.0514
# Epoch [1/15], Step [721/937], Loss: 2.9684
# Epoch [1/15], Step [741/937], Loss: 3.0017
# Epoch [1/15], Step [761/937], Loss: 2.9647
# Epoch [1/15], Step [781/937], Loss: 2.9244
# Epoch [1/15], Step [801/937], Loss: 2.9359
# Epoch [1/15], Step [821/937], Loss: 2.9611
# Epoch [1/15], Step [841/937], Loss: 2.9154
# Epoch [1/15], Step [861/937], Loss: 2.9519
# Epoch [1/15], Step [881/937], Loss: 2.8686
# Epoch [1/15], Step [901/937], Loss: 2.8987
# Epoch [1/15], Step [921/937], Loss: 2.9096
# Epoch [2/15], Step [1/937], Loss: 2.8838
# Epoch [2/15], Step [21/937], Loss: 2.8324
# Epoch [2/15], Step [41/937], Loss: 2.9065
# Epoch [2/15], Step [61/937], Loss: 2.9004
# Epoch [2/15], Step [81/937], Loss: 2.8160
# Epoch [2/15], Step [101/937], Loss: 2.8554
# Epoch [2/15], Step [121/937], Loss: 2.8221
# Epoch [2/15], Step [141/937], Loss: 2.8110
# Epoch [2/15], Step [161/937], Loss: 2.7977
# Epoch [2/15], Step [181/937], Loss: 2.6947
# Epoch [2/15], Step [201/937], Loss: 2.7653
# Epoch [2/15], Step [221/937], Loss: 2.8463
# Epoch [2/15], Step [241/937], Loss: 2.7310
# Epoch [2/15], Step [261/937], Loss: 2.7675
# Epoch [2/15], Step [281/937], Loss: 2.6686
# Epoch [2/15], Step [301/937], Loss: 2.7099
# Epoch [2/15], Step [321/937], Loss: 2.6508
# Epoch [2/15], Step [341/937], Loss: 2.6572
# Epoch [2/15], Step [361/937], Loss: 2.6440
# Epoch [2/15], Step [381/937], Loss: 2.6332
# Epoch [2/15], Step [401/937], Loss: 2.6641
# Epoch [2/15], Step [421/937], Loss: 2.6394
# Epoch [2/15], Step [441/937], Loss: 2.5582
# Epoch [2/15], Step [461/937], Loss: 2.6028
# Epoch [2/15], Step [481/937], Loss: 2.5972
# Epoch [2/15], Step [501/937], Loss: 2.4576
# Epoch [2/15], Step [521/937], Loss: 2.5542
# Epoch [2/15], Step [541/937], Loss: 2.4709
# Epoch [2/15], Step [561/937], Loss: 2.4877
# Epoch [2/15], Step [581/937], Loss: 2.4715
# Epoch [2/15], Step [601/937], Loss: 2.4899
# Epoch [2/15], Step [621/937], Loss: 2.4707
# Epoch [2/15], Step [641/937], Loss: 2.4459
# Epoch [2/15], Step [661/937], Loss: 2.3967
# Epoch [2/15], Step [681/937], Loss: 2.4410
# Epoch [2/15], Step [701/937], Loss: 2.3947
# Epoch [2/15], Step [721/937], Loss: 2.4109
# Epoch [2/15], Step [741/937], Loss: 2.4836
# Epoch [2/15], Step [761/937], Loss: 2.2600
# Epoch [2/15], Step [781/937], Loss: 2.3060
# Epoch [2/15], Step [801/937], Loss: 2.3699
# Epoch [2/15], Step [821/937], Loss: 2.3764
# Epoch [2/15], Step [841/937], Loss: 2.4045
# Epoch [2/15], Step [861/937], Loss: 2.3438
# Epoch [2/15], Step [881/937], Loss: 2.3815
# Epoch [2/15], Step [901/937], Loss: 2.2276
# Epoch [2/15], Step [921/937], Loss: 2.2508
# Epoch [3/15], Step [1/937], Loss: 2.2058
# Epoch [3/15], Step [21/937], Loss: 2.1166
# Epoch [3/15], Step [41/937], Loss: 2.1618
# Epoch [3/15], Step [61/937], Loss: 2.1205
# Epoch [3/15], Step [81/937], Loss: 2.2124
# Epoch [3/15], Step [101/937], Loss: 2.2152
# Epoch [3/15], Step [121/937], Loss: 2.2170
# Epoch [3/15], Step [141/937], Loss: 2.1021
# Epoch [3/15], Step [161/937], Loss: 2.2188
# Epoch [3/15], Step [181/937], Loss: 2.2543
# Epoch [3/15], Step [201/937], Loss: 1.9259
# Epoch [3/15], Step [221/937], Loss: 1.9230
# Epoch [3/15], Step [241/937], Loss: 2.0011
# Epoch [3/15], Step [261/937], Loss: 2.0758
# Epoch [3/15], Step [281/937], Loss: 2.0028
# Epoch [3/15], Step [301/937], Loss: 2.1360
# Epoch [3/15], Step [321/937], Loss: 1.9833
# Epoch [3/15], Step [341/937], Loss: 1.7527
# Epoch [3/15], Step [361/937], Loss: 1.9558
# Epoch [3/15], Step [381/937], Loss: 2.0813
# Epoch [3/15], Step [401/937], Loss: 2.0589
# Epoch [3/15], Step [421/937], Loss: 1.8541
# Epoch [3/15], Step [441/937], Loss: 2.0592
# Epoch [3/15], Step [461/937], Loss: 1.7826
# Epoch [3/15], Step [481/937], Loss: 2.0300
# Epoch [3/15], Step [501/937], Loss: 1.7845
# Epoch [3/15], Step [521/937], Loss: 1.8545
# Epoch [3/15], Step [541/937], Loss: 1.8900
# Epoch [3/15], Step [561/937], Loss: 1.7288
# Epoch [3/15], Step [581/937], Loss: 1.6957
# Epoch [3/15], Step [601/937], Loss: 1.8531
# Epoch [3/15], Step [621/937], Loss: 1.6067
# Epoch [3/15], Step [641/937], Loss: 1.7414
# Epoch [3/15], Step [661/937], Loss: 1.8994
# Epoch [3/15], Step [681/937], Loss: 1.7758
# Epoch [3/15], Step [701/937], Loss: 1.6475
# Epoch [3/15], Step [721/937], Loss: 1.7170
# Epoch [3/15], Step [741/937], Loss: 1.5382
# Epoch [3/15], Step [761/937], Loss: 1.8927
# Epoch [3/15], Step [781/937], Loss: 1.6810
# Epoch [3/15], Step [801/937], Loss: 1.6503
# Epoch [3/15], Step [821/937], Loss: 1.5552
# Epoch [3/15], Step [841/937], Loss: 1.6713
# Epoch [3/15], Step [861/937], Loss: 1.6694
# Epoch [3/15], Step [881/937], Loss: 1.6752
# Epoch [3/15], Step [901/937], Loss: 1.6330
# Epoch [3/15], Step [921/937], Loss: 1.5483
# Epoch [4/15], Step [1/937], Loss: 1.5547
# Epoch [4/15], Step [21/937], Loss: 1.6650
# Epoch [4/15], Step [41/937], Loss: 1.5496
# Epoch [4/15], Step [61/937], Loss: 1.5714
# Epoch [4/15], Step [81/937], Loss: 1.6627
# Epoch [4/15], Step [101/937], Loss: 1.6759
# Epoch [4/15], Step [121/937], Loss: 1.6737
# Epoch [4/15], Step [141/937], Loss: 1.3613
# Epoch [4/15], Step [161/937], Loss: 1.4610
# Epoch [4/15], Step [181/937], Loss: 1.3866
# Epoch [4/15], Step [201/937], Loss: 1.4477
# Epoch [4/15], Step [221/937], Loss: 1.5127
# Epoch [4/15], Step [241/937], Loss: 1.2497
# Epoch [4/15], Step [261/937], Loss: 1.2566
# Epoch [4/15], Step [281/937], Loss: 1.6523
# Epoch [4/15], Step [301/937], Loss: 1.4494
# Epoch [4/15], Step [321/937], Loss: 1.3871
# Epoch [4/15], Step [341/937], Loss: 1.5432
# Epoch [4/15], Step [361/937], Loss: 1.4065
# Epoch [4/15], Step [381/937], Loss: 1.3927
# Epoch [4/15], Step [401/937], Loss: 1.3374
# Epoch [4/15], Step [421/937], Loss: 1.2525
# Epoch [4/15], Step [441/937], Loss: 1.4047
# Epoch [4/15], Step [461/937], Loss: 1.4108
# Epoch [4/15], Step [481/937], Loss: 1.5907
# Epoch [4/15], Step [501/937], Loss: 1.4270
# Epoch [4/15], Step [521/937], Loss: 1.4110
# Epoch [4/15], Step [541/937], Loss: 1.4168
# Epoch [4/15], Step [561/937], Loss: 1.3985
# Epoch [4/15], Step [581/937], Loss: 1.2635
# Epoch [4/15], Step [601/937], Loss: 1.4020
# Epoch [4/15], Step [621/937], Loss: 1.2281
# Epoch [4/15], Step [641/937], Loss: 1.3334
# Epoch [4/15], Step [661/937], Loss: 1.0882
# Epoch [4/15], Step [681/937], Loss: 1.3747
# Epoch [4/15], Step [701/937], Loss: 1.2039
# Epoch [4/15], Step [721/937], Loss: 1.4043
# Epoch [4/15], Step [741/937], Loss: 1.4145
# Epoch [4/15], Step [761/937], Loss: 1.3210
# Epoch [4/15], Step [781/937], Loss: 1.3046
# Epoch [4/15], Step [801/937], Loss: 1.1819
# Epoch [4/15], Step [821/937], Loss: 1.4213
# Epoch [4/15], Step [841/937], Loss: 1.1513
# Epoch [4/15], Step [861/937], Loss: 1.6207
# Epoch [4/15], Step [881/937], Loss: 1.1760
# Epoch [4/15], Step [901/937], Loss: 1.2221
# Epoch [4/15], Step [921/937], Loss: 1.3194
# Epoch [5/15], Step [1/937], Loss: 1.2016
# Epoch [5/15], Step [21/937], Loss: 1.2614
# Epoch [5/15], Step [41/937], Loss: 0.9711
# Epoch [5/15], Step [61/937], Loss: 1.2436
# Epoch [5/15], Step [81/937], Loss: 1.2027
# Epoch [5/15], Step [101/937], Loss: 1.1762
# Epoch [5/15], Step [121/937], Loss: 1.1519
# Epoch [5/15], Step [141/937], Loss: 1.3229
# Epoch [5/15], Step [161/937], Loss: 1.1102
# Epoch [5/15], Step [181/937], Loss: 1.2696
# Epoch [5/15], Step [201/937], Loss: 1.1507
# Epoch [5/15], Step [221/937], Loss: 1.2965
# Epoch [5/15], Step [241/937], Loss: 1.0980
# Epoch [5/15], Step [261/937], Loss: 1.1042
# Epoch [5/15], Step [281/937], Loss: 1.1245
# Epoch [5/15], Step [301/937], Loss: 1.1879
# Epoch [5/15], Step [321/937], Loss: 1.3391
# Epoch [5/15], Step [341/937], Loss: 1.1032
# Epoch [5/15], Step [361/937], Loss: 1.2335
# Epoch [5/15], Step [381/937], Loss: 1.0489
# Epoch [5/15], Step [401/937], Loss: 1.3224
# Epoch [5/15], Step [421/937], Loss: 1.2749
# Epoch [5/15], Step [441/937], Loss: 1.1017
# Epoch [5/15], Step [461/937], Loss: 1.2538
# Epoch [5/15], Step [481/937], Loss: 0.8803
# Epoch [5/15], Step [501/937], Loss: 0.9185
# Epoch [5/15], Step [521/937], Loss: 1.1503
# Epoch [5/15], Step [541/937], Loss: 1.0437
# Epoch [5/15], Step [561/937], Loss: 1.1039
# Epoch [5/15], Step [581/937], Loss: 1.2452
# Epoch [5/15], Step [601/937], Loss: 0.9246
# Epoch [5/15], Step [621/937], Loss: 1.1202
# Epoch [5/15], Step [641/937], Loss: 0.8862
# Epoch [5/15], Step [661/937], Loss: 0.9603
# Epoch [5/15], Step [681/937], Loss: 1.1592
# Epoch [5/15], Step [701/937], Loss: 1.0770
# Epoch [5/15], Step [721/937], Loss: 1.0854
# Epoch [5/15], Step [741/937], Loss: 1.1989
# Epoch [5/15], Step [761/937], Loss: 0.9564
# Epoch [5/15], Step [781/937], Loss: 1.2269
# Epoch [5/15], Step [801/937], Loss: 1.1808
# Epoch [5/15], Step [821/937], Loss: 0.8424
# Epoch [5/15], Step [841/937], Loss: 0.9868
# Epoch [5/15], Step [861/937], Loss: 1.1531
# Epoch [5/15], Step [881/937], Loss: 1.1017
# Epoch [5/15], Step [901/937], Loss: 0.9691
# Epoch [5/15], Step [921/937], Loss: 0.9812
# Epoch [6/15], Step [1/937], Loss: 1.1409
# Epoch [6/15], Step [21/937], Loss: 1.2917
# Epoch [6/15], Step [41/937], Loss: 0.9152
# Epoch [6/15], Step [61/937], Loss: 0.8933
# Epoch [6/15], Step [81/937], Loss: 1.0599
# Epoch [6/15], Step [101/937], Loss: 0.8410
# Epoch [6/15], Step [121/937], Loss: 1.1580
# Epoch [6/15], Step [141/937], Loss: 1.0646
# Epoch [6/15], Step [161/937], Loss: 1.1088
# Epoch [6/15], Step [181/937], Loss: 0.9418
# Epoch [6/15], Step [201/937], Loss: 1.0948
# Epoch [6/15], Step [221/937], Loss: 1.1622
# Epoch [6/15], Step [241/937], Loss: 0.8567
# Epoch [6/15], Step [261/937], Loss: 0.8653
# Epoch [6/15], Step [281/937], Loss: 1.0297
# Epoch [6/15], Step [301/937], Loss: 0.8550
# Epoch [6/15], Step [321/937], Loss: 0.9250
# Epoch [6/15], Step [341/937], Loss: 0.9682
# Epoch [6/15], Step [361/937], Loss: 0.9721
# Epoch [6/15], Step [381/937], Loss: 0.8105
# Epoch [6/15], Step [401/937], Loss: 0.9460
# Epoch [6/15], Step [421/937], Loss: 0.8861
# Epoch [6/15], Step [441/937], Loss: 0.9971
# Epoch [6/15], Step [461/937], Loss: 0.8917
# Epoch [6/15], Step [481/937], Loss: 0.8867
# Epoch [6/15], Step [501/937], Loss: 0.8883
# Epoch [6/15], Step [521/937], Loss: 0.9251
# Epoch [6/15], Step [541/937], Loss: 1.0722
# Epoch [6/15], Step [561/937], Loss: 0.9346
# Epoch [6/15], Step [581/937], Loss: 1.0041
# Epoch [6/15], Step [601/937], Loss: 1.0346
# Epoch [6/15], Step [621/937], Loss: 0.9189
# Epoch [6/15], Step [641/937], Loss: 0.8605
# Epoch [6/15], Step [661/937], Loss: 0.8145
# Epoch [6/15], Step [681/937], Loss: 0.7681
# Epoch [6/15], Step [701/937], Loss: 0.9369
# Epoch [6/15], Step [721/937], Loss: 0.9313
# Epoch [6/15], Step [741/937], Loss: 0.9378
# Epoch [6/15], Step [761/937], Loss: 0.9490
# Epoch [6/15], Step [781/937], Loss: 1.1748
# Epoch [6/15], Step [801/937], Loss: 0.9752
# Epoch [6/15], Step [821/937], Loss: 0.8028
# Epoch [6/15], Step [841/937], Loss: 0.9005
# Epoch [6/15], Step [861/937], Loss: 0.9778
# Epoch [6/15], Step [881/937], Loss: 0.7099
# Epoch [6/15], Step [901/937], Loss: 0.7077
# Epoch [6/15], Step [921/937], Loss: 0.9266
# Epoch [7/15], Step [1/937], Loss: 0.9702
# Epoch [7/15], Step [21/937], Loss: 0.6791
# Epoch [7/15], Step [41/937], Loss: 0.7457
# Epoch [7/15], Step [61/937], Loss: 0.7959
# Epoch [7/15], Step [81/937], Loss: 0.8951
# Epoch [7/15], Step [101/937], Loss: 0.8487
# Epoch [7/15], Step [121/937], Loss: 0.7537
# Epoch [7/15], Step [141/937], Loss: 1.1347
# Epoch [7/15], Step [161/937], Loss: 0.7804
# Epoch [7/15], Step [181/937], Loss: 1.1084
# Epoch [7/15], Step [201/937], Loss: 0.7986
# Epoch [7/15], Step [221/937], Loss: 1.0530
# Epoch [7/15], Step [241/937], Loss: 1.1089
# Epoch [7/15], Step [261/937], Loss: 0.7806
# Epoch [7/15], Step [281/937], Loss: 0.8706
# Epoch [7/15], Step [301/937], Loss: 1.3140
# Epoch [7/15], Step [321/937], Loss: 0.9085
# Epoch [7/15], Step [341/937], Loss: 0.8235
# Epoch [7/15], Step [361/937], Loss: 1.0270
# Epoch [7/15], Step [381/937], Loss: 0.6459
# Epoch [7/15], Step [401/937], Loss: 0.9477
# Epoch [7/15], Step [421/937], Loss: 0.8069
# Epoch [7/15], Step [441/937], Loss: 0.9890
# Epoch [7/15], Step [461/937], Loss: 0.7608
# Epoch [7/15], Step [481/937], Loss: 0.9763
# Epoch [7/15], Step [501/937], Loss: 0.6659
# Epoch [7/15], Step [521/937], Loss: 1.0161
# Epoch [7/15], Step [541/937], Loss: 0.8666
# Epoch [7/15], Step [561/937], Loss: 0.9599
# Epoch [7/15], Step [581/937], Loss: 0.9038
# Epoch [7/15], Step [601/937], Loss: 0.8541
# Epoch [7/15], Step [621/937], Loss: 0.8421
# Epoch [7/15], Step [641/937], Loss: 1.0039
# Epoch [7/15], Step [661/937], Loss: 0.5685
# Epoch [7/15], Step [681/937], Loss: 0.8430
# Epoch [7/15], Step [701/937], Loss: 1.0162
# Epoch [7/15], Step [721/937], Loss: 0.8781
# Epoch [7/15], Step [741/937], Loss: 0.7503
# Epoch [7/15], Step [761/937], Loss: 0.8692
# Epoch [7/15], Step [781/937], Loss: 1.0197
# Epoch [7/15], Step [801/937], Loss: 0.7103
# Epoch [7/15], Step [821/937], Loss: 0.9073
# Epoch [7/15], Step [841/937], Loss: 0.8888
# Epoch [7/15], Step [861/937], Loss: 0.9483
# Epoch [7/15], Step [881/937], Loss: 0.7119
# Epoch [7/15], Step [901/937], Loss: 0.9392
# Epoch [7/15], Step [921/937], Loss: 0.9337
# Epoch [8/15], Step [1/937], Loss: 1.0366
# Epoch [8/15], Step [21/937], Loss: 0.8732
# Epoch [8/15], Step [41/937], Loss: 0.8593
# Epoch [8/15], Step [61/937], Loss: 0.7102
# Epoch [8/15], Step [81/937], Loss: 0.5376
# Epoch [8/15], Step [101/937], Loss: 0.9181
# Epoch [8/15], Step [121/937], Loss: 0.5934
# Epoch [8/15], Step [141/937], Loss: 0.8990
# Epoch [8/15], Step [161/937], Loss: 0.6933
# Epoch [8/15], Step [181/937], Loss: 0.8146
# Epoch [8/15], Step [201/937], Loss: 0.6945
# Epoch [8/15], Step [221/937], Loss: 0.7315
# Epoch [8/15], Step [241/937], Loss: 0.5020
# Epoch [8/15], Step [261/937], Loss: 0.7443
# Epoch [8/15], Step [281/937], Loss: 0.7935
# Epoch [8/15], Step [301/937], Loss: 0.6836
# Epoch [8/15], Step [321/937], Loss: 0.5133
# Epoch [8/15], Step [341/937], Loss: 0.7386
# Epoch [8/15], Step [361/937], Loss: 0.4406
# Epoch [8/15], Step [381/937], Loss: 0.5928
# Epoch [8/15], Step [401/937], Loss: 0.7933
# Epoch [8/15], Step [421/937], Loss: 0.9095
# Epoch [8/15], Step [441/937], Loss: 0.6182
# Epoch [8/15], Step [461/937], Loss: 0.8478
# Epoch [8/15], Step [481/937], Loss: 0.7085
# Epoch [8/15], Step [501/937], Loss: 0.6743
# Epoch [8/15], Step [521/937], Loss: 0.9121
# Epoch [8/15], Step [541/937], Loss: 0.6843
# Epoch [8/15], Step [561/937], Loss: 1.1586
# Epoch [8/15], Step [581/937], Loss: 0.7504
# Epoch [8/15], Step [601/937], Loss: 0.5941
# Epoch [8/15], Step [621/937], Loss: 0.6238
# Epoch [8/15], Step [641/937], Loss: 0.5677
# Epoch [8/15], Step [661/937], Loss: 0.8787
# Epoch [8/15], Step [681/937], Loss: 0.6853
# Epoch [8/15], Step [701/937], Loss: 0.5299
# Epoch [8/15], Step [721/937], Loss: 0.9741
# Epoch [8/15], Step [741/937], Loss: 0.7491
# Epoch [8/15], Step [761/937], Loss: 0.6979
# Epoch [8/15], Step [781/937], Loss: 0.8105
# Epoch [8/15], Step [801/937], Loss: 0.7851
# Epoch [8/15], Step [821/937], Loss: 0.6659
# Epoch [8/15], Step [841/937], Loss: 0.6492
# Epoch [8/15], Step [861/937], Loss: 0.6976
# Epoch [8/15], Step [881/937], Loss: 0.7548
# Epoch [8/15], Step [901/937], Loss: 0.6584
# Epoch [8/15], Step [921/937], Loss: 0.9125
# Epoch [9/15], Step [1/937], Loss: 0.8141
# Epoch [9/15], Step [21/937], Loss: 0.7811
# Epoch [9/15], Step [41/937], Loss: 0.5215
# Epoch [9/15], Step [61/937], Loss: 0.5410
# Epoch [9/15], Step [81/937], Loss: 0.7930
# Epoch [9/15], Step [101/937], Loss: 0.5708
# Epoch [9/15], Step [121/937], Loss: 0.9279
# Epoch [9/15], Step [141/937], Loss: 0.8372
# Epoch [9/15], Step [161/937], Loss: 0.5916
# Epoch [9/15], Step [181/937], Loss: 0.5295
# Epoch [9/15], Step [201/937], Loss: 0.7225
# Epoch [9/15], Step [221/937], Loss: 0.8483
# Epoch [9/15], Step [241/937], Loss: 0.6742
# Epoch [9/15], Step [261/937], Loss: 0.6787
# Epoch [9/15], Step [281/937], Loss: 0.6248
# Epoch [9/15], Step [301/937], Loss: 0.8634
# Epoch [9/15], Step [321/937], Loss: 0.8111
# Epoch [9/15], Step [341/937], Loss: 0.6993
# Epoch [9/15], Step [361/937], Loss: 0.6606
# Epoch [9/15], Step [381/937], Loss: 0.7321
# Epoch [9/15], Step [401/937], Loss: 0.6036
# Epoch [9/15], Step [421/937], Loss: 0.6619
# Epoch [9/15], Step [441/937], Loss: 0.6192
# Epoch [9/15], Step [461/937], Loss: 0.9491
# Epoch [9/15], Step [481/937], Loss: 0.5904
# Epoch [9/15], Step [501/937], Loss: 0.5836
# Epoch [9/15], Step [521/937], Loss: 0.7370
# Epoch [9/15], Step [541/937], Loss: 0.7767
# Epoch [9/15], Step [561/937], Loss: 0.8180
# Epoch [9/15], Step [581/937], Loss: 0.5443
# Epoch [9/15], Step [601/937], Loss: 0.6822
# Epoch [9/15], Step [621/937], Loss: 0.5512
# Epoch [9/15], Step [641/937], Loss: 0.7025
# Epoch [9/15], Step [661/937], Loss: 0.7852
# Epoch [9/15], Step [681/937], Loss: 0.5726
# Epoch [9/15], Step [701/937], Loss: 1.0010
# Epoch [9/15], Step [721/937], Loss: 0.6985
# Epoch [9/15], Step [741/937], Loss: 0.9118
# Epoch [9/15], Step [761/937], Loss: 0.6306
# Epoch [9/15], Step [781/937], Loss: 0.6633
# Epoch [9/15], Step [801/937], Loss: 0.6791
# Epoch [9/15], Step [821/937], Loss: 0.4721
# Epoch [9/15], Step [841/937], Loss: 0.4437
# Epoch [9/15], Step [861/937], Loss: 0.8172
# Epoch [9/15], Step [881/937], Loss: 0.5669
# Epoch [9/15], Step [901/937], Loss: 0.6402
# Epoch [9/15], Step [921/937], Loss: 0.7254
# Epoch [10/15], Step [1/937], Loss: 0.7030
# Epoch [10/15], Step [21/937], Loss: 0.5958
# Epoch [10/15], Step [41/937], Loss: 0.6727
# Epoch [10/15], Step [61/937], Loss: 0.4978
# Epoch [10/15], Step [81/937], Loss: 0.7377
# Epoch [10/15], Step [101/937], Loss: 0.4370
# Epoch [10/15], Step [121/937], Loss: 0.6996
# Epoch [10/15], Step [141/937], Loss: 0.6909
# Epoch [10/15], Step [161/937], Loss: 0.4758
# Epoch [10/15], Step [181/937], Loss: 0.7250
# Epoch [10/15], Step [201/937], Loss: 0.5687
# Epoch [10/15], Step [221/937], Loss: 0.5722
# Epoch [10/15], Step [241/937], Loss: 0.4281
# Epoch [10/15], Step [261/937], Loss: 0.4979
# Epoch [10/15], Step [281/937], Loss: 0.6289
# Epoch [10/15], Step [301/937], Loss: 0.6109
# Epoch [10/15], Step [321/937], Loss: 0.7990
# Epoch [10/15], Step [341/937], Loss: 0.7695
# Epoch [10/15], Step [361/937], Loss: 0.7609
# Epoch [10/15], Step [381/937], Loss: 0.6219
# Epoch [10/15], Step [401/937], Loss: 0.6964
# Epoch [10/15], Step [421/937], Loss: 0.7500
# Epoch [10/15], Step [441/937], Loss: 0.6685
# Epoch [10/15], Step [461/937], Loss: 0.7647
# Epoch [10/15], Step [481/937], Loss: 0.5992
# Epoch [10/15], Step [501/937], Loss: 0.7191
# Epoch [10/15], Step [521/937], Loss: 0.7192
# Epoch [10/15], Step [541/937], Loss: 0.5676
# Epoch [10/15], Step [561/937], Loss: 0.6115
# Epoch [10/15], Step [581/937], Loss: 0.6923
# Epoch [10/15], Step [601/937], Loss: 0.6266
# Epoch [10/15], Step [621/937], Loss: 0.5401
# Epoch [10/15], Step [641/937], Loss: 0.7796
# Epoch [10/15], Step [661/937], Loss: 0.6055
# Epoch [10/15], Step [681/937], Loss: 0.9419
# Epoch [10/15], Step [701/937], Loss: 0.6016
# Epoch [10/15], Step [721/937], Loss: 0.6401
# Epoch [10/15], Step [741/937], Loss: 0.5079
# Epoch [10/15], Step [761/937], Loss: 0.5239
# Epoch [10/15], Step [781/937], Loss: 0.5601
# Epoch [10/15], Step [801/937], Loss: 0.5656
# Epoch [10/15], Step [821/937], Loss: 0.6238
# Epoch [10/15], Step [841/937], Loss: 0.6910
# Epoch [10/15], Step [861/937], Loss: 0.6625
# Epoch [10/15], Step [881/937], Loss: 0.8475
# Epoch [10/15], Step [901/937], Loss: 0.8928
# Epoch [10/15], Step [921/937], Loss: 0.6543
# Epoch [11/15], Step [1/937], Loss: 0.4270
# Epoch [11/15], Step [21/937], Loss: 0.5227
# Epoch [11/15], Step [41/937], Loss: 0.6370
# Epoch [11/15], Step [61/937], Loss: 0.6007
# Epoch [11/15], Step [81/937], Loss: 0.8764
# Epoch [11/15], Step [101/937], Loss: 0.6735
# Epoch [11/15], Step [121/937], Loss: 0.4616
# Epoch [11/15], Step [141/937], Loss: 0.5946
# Epoch [11/15], Step [161/937], Loss: 0.6346
# Epoch [11/15], Step [181/937], Loss: 0.5915
# Epoch [11/15], Step [201/937], Loss: 0.7843
# Epoch [11/15], Step [221/937], Loss: 0.6323
# Epoch [11/15], Step [241/937], Loss: 0.6545
# Epoch [11/15], Step [261/937], Loss: 0.6061
# Epoch [11/15], Step [281/937], Loss: 0.5027
# Epoch [11/15], Step [301/937], Loss: 0.6163
# Epoch [11/15], Step [321/937], Loss: 0.5577
# Epoch [11/15], Step [341/937], Loss: 0.6313
# Epoch [11/15], Step [361/937], Loss: 0.7305
# Epoch [11/15], Step [381/937], Loss: 0.7133
# Epoch [11/15], Step [401/937], Loss: 0.5502
# Epoch [11/15], Step [421/937], Loss: 0.5651
# Epoch [11/15], Step [441/937], Loss: 0.6324
# Epoch [11/15], Step [461/937], Loss: 0.5974
# Epoch [11/15], Step [481/937], Loss: 0.6138
# Epoch [11/15], Step [501/937], Loss: 0.8320
# Epoch [11/15], Step [521/937], Loss: 0.6045
# Epoch [11/15], Step [541/937], Loss: 0.4279
# Epoch [11/15], Step [561/937], Loss: 0.7926
# Epoch [11/15], Step [581/937], Loss: 0.9242
# Epoch [11/15], Step [601/937], Loss: 0.6779
# Epoch [11/15], Step [621/937], Loss: 0.4401
# Epoch [11/15], Step [641/937], Loss: 1.1106
# Epoch [11/15], Step [661/937], Loss: 0.7767
# Epoch [11/15], Step [681/937], Loss: 0.5965
# Epoch [11/15], Step [701/937], Loss: 0.5279
# Epoch [11/15], Step [721/937], Loss: 0.6514
# Epoch [11/15], Step [741/937], Loss: 0.6084
# Epoch [11/15], Step [761/937], Loss: 0.6065
# Epoch [11/15], Step [781/937], Loss: 0.7268
# Epoch [11/15], Step [801/937], Loss: 0.5750
# Epoch [11/15], Step [821/937], Loss: 0.8896
# Epoch [11/15], Step [841/937], Loss: 0.3603
# Epoch [11/15], Step [861/937], Loss: 0.7784
# Epoch [11/15], Step [881/937], Loss: 0.5527
# Epoch [11/15], Step [901/937], Loss: 0.6076
# Epoch [11/15], Step [921/937], Loss: 0.5491
# Epoch [12/15], Step [1/937], Loss: 0.6155
# Epoch [12/15], Step [21/937], Loss: 0.5262
# Epoch [12/15], Step [41/937], Loss: 0.5552
# Epoch [12/15], Step [61/937], Loss: 0.4870
# Epoch [12/15], Step [81/937], Loss: 0.6594
# Epoch [12/15], Step [101/937], Loss: 0.7404
# Epoch [12/15], Step [121/937], Loss: 0.5913
# Epoch [12/15], Step [141/937], Loss: 0.8999
# Epoch [12/15], Step [161/937], Loss: 0.7720
# Epoch [12/15], Step [181/937], Loss: 0.4681
# Epoch [12/15], Step [201/937], Loss: 0.5262
# Epoch [12/15], Step [221/937], Loss: 0.7441
# Epoch [12/15], Step [241/937], Loss: 0.5956
# Epoch [12/15], Step [261/937], Loss: 0.4981
# Epoch [12/15], Step [281/937], Loss: 0.8440
# Epoch [12/15], Step [301/937], Loss: 0.5735
# Epoch [12/15], Step [321/937], Loss: 0.5351
# Epoch [12/15], Step [341/937], Loss: 0.6336
# Epoch [12/15], Step [361/937], Loss: 0.8424
# Epoch [12/15], Step [381/937], Loss: 0.6413
# Epoch [12/15], Step [401/937], Loss: 0.6940
# Epoch [12/15], Step [421/937], Loss: 0.6357
# Epoch [12/15], Step [441/937], Loss: 0.5627
# Epoch [12/15], Step [461/937], Loss: 0.4620
# Epoch [12/15], Step [481/937], Loss: 0.6562
# Epoch [12/15], Step [501/937], Loss: 0.5446
# Epoch [12/15], Step [521/937], Loss: 0.5327
# Epoch [12/15], Step [541/937], Loss: 0.5591
# Epoch [12/15], Step [561/937], Loss: 0.5985
# Epoch [12/15], Step [581/937], Loss: 0.3154
# Epoch [12/15], Step [601/937], Loss: 0.7575
# Epoch [12/15], Step [621/937], Loss: 0.6505
# Epoch [12/15], Step [641/937], Loss: 0.4915
# Epoch [12/15], Step [661/937], Loss: 0.5233
# Epoch [12/15], Step [681/937], Loss: 0.6466
# Epoch [12/15], Step [701/937], Loss: 0.6562
# Epoch [12/15], Step [721/937], Loss: 0.5550
# Epoch [12/15], Step [741/937], Loss: 0.3512
# Epoch [12/15], Step [761/937], Loss: 0.4325
# Epoch [12/15], Step [781/937], Loss: 0.5520
# Epoch [12/15], Step [801/937], Loss: 0.4902
# Epoch [12/15], Step [821/937], Loss: 0.8116
# Epoch [12/15], Step [841/937], Loss: 0.4255
# Epoch [12/15], Step [861/937], Loss: 1.0364
# Epoch [12/15], Step [881/937], Loss: 0.4652
# Epoch [12/15], Step [901/937], Loss: 0.4695
# Epoch [12/15], Step [921/937], Loss: 0.5255
# Epoch [13/15], Step [1/937], Loss: 0.2757
# Epoch [13/15], Step [21/937], Loss: 0.5254
# Epoch [13/15], Step [41/937], Loss: 0.5219
# Epoch [13/15], Step [61/937], Loss: 0.5120
# Epoch [13/15], Step [81/937], Loss: 0.6651
# Epoch [13/15], Step [101/937], Loss: 0.4630
# Epoch [13/15], Step [121/937], Loss: 0.6391
# Epoch [13/15], Step [141/937], Loss: 0.5544
# Epoch [13/15], Step [161/937], Loss: 0.5276
# Epoch [13/15], Step [181/937], Loss: 0.4035
# Epoch [13/15], Step [201/937], Loss: 0.4663
# Epoch [13/15], Step [221/937], Loss: 0.3708
# Epoch [13/15], Step [241/937], Loss: 0.5209
# Epoch [13/15], Step [261/937], Loss: 0.4217
# Epoch [13/15], Step [281/937], Loss: 0.5159
# Epoch [13/15], Step [301/937], Loss: 0.6549
# Epoch [13/15], Step [321/937], Loss: 0.7862
# Epoch [13/15], Step [341/937], Loss: 0.6749
# Epoch [13/15], Step [361/937], Loss: 0.4374
# Epoch [13/15], Step [381/937], Loss: 0.4583
# Epoch [13/15], Step [401/937], Loss: 0.6113
# Epoch [13/15], Step [421/937], Loss: 0.5512
# Epoch [13/15], Step [441/937], Loss: 0.6851
# Epoch [13/15], Step [461/937], Loss: 0.5315
# Epoch [13/15], Step [481/937], Loss: 0.4887
# Epoch [13/15], Step [501/937], Loss: 0.5723
# Epoch [13/15], Step [521/937], Loss: 0.6070
# Epoch [13/15], Step [541/937], Loss: 0.5203
# Epoch [13/15], Step [561/937], Loss: 0.5838
# Epoch [13/15], Step [581/937], Loss: 0.7397
# Epoch [13/15], Step [601/937], Loss: 0.5588
# Epoch [13/15], Step [621/937], Loss: 0.6369
# Epoch [13/15], Step [641/937], Loss: 0.6329
# Epoch [13/15], Step [661/937], Loss: 0.6285
# Epoch [13/15], Step [681/937], Loss: 0.4786
# Epoch [13/15], Step [701/937], Loss: 0.4723
# Epoch [13/15], Step [721/937], Loss: 0.6014
# Epoch [13/15], Step [741/937], Loss: 0.5160
# Epoch [13/15], Step [761/937], Loss: 0.6291
# Epoch [13/15], Step [781/937], Loss: 0.5615
# Epoch [13/15], Step [801/937], Loss: 0.4782
# Epoch [13/15], Step [821/937], Loss: 0.9560
# Epoch [13/15], Step [841/937], Loss: 0.7477
# Epoch [13/15], Step [861/937], Loss: 0.6266
# Epoch [13/15], Step [881/937], Loss: 0.6651
# Epoch [13/15], Step [901/937], Loss: 0.3276
# Epoch [13/15], Step [921/937], Loss: 0.7265
# Epoch [14/15], Step [1/937], Loss: 0.4840
# Epoch [14/15], Step [21/937], Loss: 0.8607
# Epoch [14/15], Step [41/937], Loss: 0.5810
# Epoch [14/15], Step [61/937], Loss: 0.4454
# Epoch [14/15], Step [81/937], Loss: 0.6326
# Epoch [14/15], Step [101/937], Loss: 0.4790
# Epoch [14/15], Step [121/937], Loss: 0.9555
# Epoch [14/15], Step [141/937], Loss: 0.6210
# Epoch [14/15], Step [161/937], Loss: 0.4743
# Epoch [14/15], Step [181/937], Loss: 0.7342
# Epoch [14/15], Step [201/937], Loss: 0.5916
# Epoch [14/15], Step [221/937], Loss: 0.5450
# Epoch [14/15], Step [241/937], Loss: 0.5105
# Epoch [14/15], Step [261/937], Loss: 0.7125
# Epoch [14/15], Step [281/937], Loss: 0.6087
# Epoch [14/15], Step [301/937], Loss: 0.5652
# Epoch [14/15], Step [321/937], Loss: 0.6786
# Epoch [14/15], Step [341/937], Loss: 0.4454
# Epoch [14/15], Step [361/937], Loss: 0.8042
# Epoch [14/15], Step [381/937], Loss: 0.5763
# Epoch [14/15], Step [401/937], Loss: 0.5363
# Epoch [14/15], Step [421/937], Loss: 0.5025
# Epoch [14/15], Step [441/937], Loss: 0.5981
# Epoch [14/15], Step [461/937], Loss: 0.4381
# Epoch [14/15], Step [481/937], Loss: 0.5597
# Epoch [14/15], Step [501/937], Loss: 0.3759
# Epoch [14/15], Step [521/937], Loss: 0.8263
# Epoch [14/15], Step [541/937], Loss: 0.4319
# Epoch [14/15], Step [561/937], Loss: 0.3716
# Epoch [14/15], Step [581/937], Loss: 0.5483
# Epoch [14/15], Step [601/937], Loss: 0.3340
# Epoch [14/15], Step [621/937], Loss: 0.4806
# Epoch [14/15], Step [641/937], Loss: 0.6707
# Epoch [14/15], Step [661/937], Loss: 0.4814
# Epoch [14/15], Step [681/937], Loss: 0.3665
# Epoch [14/15], Step [701/937], Loss: 0.6508
# Epoch [14/15], Step [721/937], Loss: 0.8472
# Epoch [14/15], Step [741/937], Loss: 0.6275
# Epoch [14/15], Step [761/937], Loss: 0.5585
# Epoch [14/15], Step [781/937], Loss: 0.6340
# Epoch [14/15], Step [801/937], Loss: 0.9063
# Epoch [14/15], Step [821/937], Loss: 0.5450
# Epoch [14/15], Step [841/937], Loss: 0.5614
# Epoch [14/15], Step [861/937], Loss: 0.6027
# Epoch [14/15], Step [881/937], Loss: 0.5092
# Epoch [14/15], Step [901/937], Loss: 0.7153
# Epoch [14/15], Step [921/937], Loss: 0.8442
# Epoch [15/15], Step [1/937], Loss: 0.5439
# Epoch [15/15], Step [21/937], Loss: 0.5851
# Epoch [15/15], Step [41/937], Loss: 0.6145
# Epoch [15/15], Step [61/937], Loss: 0.5970
# Epoch [15/15], Step [81/937], Loss: 0.4844
# Epoch [15/15], Step [101/937], Loss: 0.7161
# Epoch [15/15], Step [121/937], Loss: 0.6202
# Epoch [15/15], Step [141/937], Loss: 0.6366
# Epoch [15/15], Step [161/937], Loss: 0.5023
# Epoch [15/15], Step [181/937], Loss: 0.5356
# Epoch [15/15], Step [201/937], Loss: 0.3330
# Epoch [15/15], Step [221/937], Loss: 0.4000
# Epoch [15/15], Step [241/937], Loss: 0.5443
# Epoch [15/15], Step [261/937], Loss: 0.5799
# Epoch [15/15], Step [281/937], Loss: 0.4280
# Epoch [15/15], Step [301/937], Loss: 0.7142
# Epoch [15/15], Step [321/937], Loss: 0.5130
# Epoch [15/15], Step [341/937], Loss: 0.3785
# Epoch [15/15], Step [361/937], Loss: 0.7677
# Epoch [15/15], Step [381/937], Loss: 0.4196
# Epoch [15/15], Step [401/937], Loss: 0.6171
# Epoch [15/15], Step [421/937], Loss: 0.4786
# Epoch [15/15], Step [441/937], Loss: 0.6580
# Epoch [15/15], Step [461/937], Loss: 0.7204
# Epoch [15/15], Step [481/937], Loss: 0.4057
# Epoch [15/15], Step [501/937], Loss: 0.6901
# Epoch [15/15], Step [521/937], Loss: 0.5928
# Epoch [15/15], Step [541/937], Loss: 0.3571
# Epoch [15/15], Step [561/937], Loss: 0.6466
# Epoch [15/15], Step [581/937], Loss: 0.6454
# Epoch [15/15], Step [601/937], Loss: 0.5974
# Epoch [15/15], Step [621/937], Loss: 0.4361
# Epoch [15/15], Step [641/937], Loss: 0.4725
# Epoch [15/15], Step [661/937], Loss: 0.4843
# Epoch [15/15], Step [681/937], Loss: 0.7573
# Epoch [15/15], Step [701/937], Loss: 0.4818
# Epoch [15/15], Step [721/937], Loss: 0.6912
# Epoch [15/15], Step [741/937], Loss: 0.4481
# Epoch [15/15], Step [761/937], Loss: 0.4177
# Epoch [15/15], Step [781/937], Loss: 0.5532
# Epoch [15/15], Step [801/937], Loss: 0.4460
# Epoch [15/15], Step [821/937], Loss: 0.6631
# Epoch [15/15], Step [841/937], Loss: 0.4615
# Epoch [15/15], Step [861/937], Loss: 0.4114
# Epoch [15/15], Step [881/937], Loss: 0.5634
# Epoch [15/15], Step [901/937], Loss: 0.5588
# Epoch [15/15], Step [921/937], Loss: 0.4809

# %%
p=len(test_dataset)
test_batches=p/batch_size
loader = torch.utils.data.DataLoader(dataset=test_dataset,batch_size = p ,shuffle=True)
dataiter = iter(loader)
data = next(dataiter)
X,y = data

X=X.numpy()
y=y.numpy()
# Flatten the images
image_vector_size = 28*28
X = X.reshape(X.shape[0], image_vector_size)
y_one_hot=convert_to_onehot(y,num_classes)
y_hat,out_cache=forward_propagation(X,trained_parameters)

test_accuracy=find_accuracy(y_one_hot,y_hat)
test_cost=compute_cost(y_hat,y_one_hot.T)

# %%
import seaborn as sn
from sklearn.metrics import confusion_matrix
k = np.argmax(y_hat,axis=0)
cm=confusion_matrix(k, y)
plt.figure(figsize=(8,8))
sn.heatmap(confusion_matrix(k, y),annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('truth')
# Out:
# Text(51.0, 0.5, 'truth')

# %%
plt.plot(train_costs)
plt.xlabel('train loss')
plt.ylabel('number of iterations')
plt.title('Train loss with ReLu activation and learning rate 0.01')
plt.show()

# %%
plt.plot(train_acc)
plt.xlabel('train accuracy')
plt.ylabel('number of iterations')
plt.title('Train accuracy with ReLu activation and learning rate 0.01')
plt.show()

# %%
m=len(train_dataset)
train_batches=m/batch_size
loader = torch.utils.data.DataLoader(dataset=train_dataset,batch_size = m ,shuffle=True)
dataiter = iter(loader)
data = next(dataiter)
X_train,y_train = data

X_train=X_train.numpy()
y_train=y_train.numpy()
# Flatten the images
image_vector_size = 28*28
X_train = X_train.reshape(X_train.shape[0], image_vector_size)
y_train_one_hot=convert_to_onehot(y_train,num_classes)
y_train_hat,out_train_cache=forward_propagation(X_train,trained_parameters)
train_accuracy_final=find_accuracy(y_train_one_hot,y_train_hat)
train_cost_final=compute_cost(y_train_hat,y_train_one_hot.T)

# %%
print(train_accuracy_final)
# Out:
# 0.90805

# %%
print(train_acc[-1])
# Out:
# 0.921875

# %%
print(test_accuracy)
# Out:
# 0.9117
