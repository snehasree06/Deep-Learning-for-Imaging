# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn 
import torchvision
import torchvision.transforms as transforms

# %%
print(torch.__version__)
# Out:
# 1.13.0.dev20220624

# %%
input_size = 784 # 28x28
hidden_layer1= 500 
hidden_layer2=250
hidden_layer3=100
num_classes = 10
num_epochs = 15
batch_size = 64
learning_rate = 0.2

# %%
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(),  download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

# %%
def convert_to_onehot(labels,num_classes):
    output = np.eye(num_classes)[np.array(labels).reshape(-1)]
    return output.reshape(list(np.shape(labels))+[num_classes])

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

def relu(x):
    return np.maximum(0, x)

def softmax(x):
    return np.exp(x)/sum(np.exp(x))

# %%
def sigmoid_derivative(x):
    return sigmoid(x) * (1- sigmoid(x))

def relu_derivative(x):
    return x>0

def softmax_derivative(x):

    return softmax(x)*(1-softmax(x))

# %%
def init_weights(No,Ni):
    M=np.sqrt(6/(Ni+No))
    weights=np.asarray(np.random.uniform(-M, M, (No, Ni)), dtype=np.float64)
    biases  = np.zeros((No,1))
    return weights,biases

# %%
def initialize_parameters(layers_dims):
    w1,b1=init_weights(layers_dims[1],layers_dims[0])
    w2,b2=init_weights(layers_dims[2],layers_dims[1])
    w3,b3=init_weights(layers_dims[3],layers_dims[2])
    w4,b4=init_weights(layers_dims[4],layers_dims[3])
    parameters={
    "w1":w1,
    "w2":w2,
    "w3":w3,
    "w4":w4,
    "b1":b1,
    "b2":b2,
    "b3":b3,
    "b4":b4
    }
    return parameters

# %%
def forward_propagation(X,parameters):
    w1=parameters['w1']
    b1=parameters['b1']
    w2=parameters['w2']
    b2=parameters['b2']
    w3=parameters['w3']
    b3=parameters['b3']
    w4=parameters['w4']
    b4=parameters['b4']
    Z1=np.dot(w1,X.T)+b1
    A1=sigmoid(Z1)
    Z2 = np.dot(w2,A1) + b2
    A2=sigmoid(Z2)
    Z3 = np.dot(w3,A2) + b3
    A3=sigmoid(Z3)
    Z4=np.dot(w4,A3)+b4
    A4=softmax(Z4)
    cache = {
        "Z1" : Z1,
        "Z2" : Z2,
        "Z3" : Z3,
        "Z4" : Z4,
        "A1" : A1,
        "A2" : A2,
        "A3" : A3,
        "A4" : A4,
        "w1" : w1,
        "b1" : b1,
        "w2" : w2,
        "b2" : b2,
        "w3" : w3,
        "b3" : b3,
        "w4" : w4,
        "b4" : b4  
    }
    return A4,cache

# %%
def compute_cost(A, Y):    
    #A is predicted
    #Y is actual
    m = Y.shape[1] 
    logprobs = np.multiply(-np.log(A),Y) + np.multiply(-np.log(1 - A), 1 - Y)
    cost = 1./m * np.nansum(logprobs)
    return cost

# %%
def backward_propagation(X, Y, cache):
    m = X.shape[1]
    A4=cache['A4']
    A3=cache['A3']
    A2=cache['A2']
    A1=cache['A1']
    Z3=cache['Z3']
    Z4=cache['Z4']
    Z2=cache['Z2']
    Z1=cache['Z1']
    w1=cache['w1']
    b1=cache['b1']
    w2=cache['w2']
    b2=cache['b2']
    w3=cache['w3']
    b3=cache['b3']
    w4=cache['w4']
    b4=cache['b4']

    dZ4 = A4 - Y
    dW4 = 1./m * np.dot(dZ4, A3.T)
    db4 = 1./m * np.sum(dZ4, axis=1, keepdims = True)
    
    dA3 = np.dot(w4.T, dZ4)
    dZ3 = np.multiply(dA3, sigmoid_derivative(Z3))
    dW3 = 1./m * np.dot(dZ3, A2.T)
    db3 = 1./m * np.sum(dZ3, axis=1, keepdims = True)
    
    dA2 = np.dot(w3.T, dZ3)
    dZ2 = np.multiply(dA2, sigmoid_derivative(Z2))
    dW2 = 1./m * np.dot(dZ2, A1.T)
    db2 = 1./m * np.sum(dZ2, axis=1, keepdims = True)

    dA1 = np.dot(w2.T, dZ2)
    dZ1 = np.multiply(dA1, sigmoid_derivative(Z1))
    dW1 = 1./m * np.dot(dZ1, X)
    db1 = 1./m * np.sum(dZ1, axis=1, keepdims = True)

    
    gradients = {"dZ4": dZ4, "dW4": dW4, "db4": db4,
                 "dA3": dA3, "dZ3": dZ3, "dW3": dW3, "db3": db3,
                 "dA2": dA2, "dZ2": dZ2, "dW2": dW2, "db2": db2,
                 "dA1": dA1, "dZ1": dZ1, "dW1": dW1, "db1": db1}
    
    return gradients

# %%
def update_parameter(parameters,gradients,learning_rate):
    w1=parameters['w1']
    b1=parameters['b1']
    w2=parameters['w2']
    b2=parameters['b2']
    w3=parameters['w3']
    b3=parameters['b3']
    w4=parameters['w4']
    b4=parameters['b4']
    dW1=gradients['dW1']
    db1=gradients['db1']
    dW2=gradients['dW2']
    db2=gradients['db2']
    dW3=gradients['dW3']
    db3=gradients['db3']
    dW4=gradients['dW4']
    db4=gradients['db4']
    w1 = w1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    w2 = w2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2
    w3 = w3 - learning_rate * dW3
    b3 = b3 - learning_rate * db3
    w4 = w4 - learning_rate * dW4
    b4 = b4 - learning_rate * db4
    
    updated_parameters={
    "w1":w1,
    "w2":w2,
    "w3":w3,
    "w4":w4,
    "b1":b1,
    "b2":b2,
    "b3":b3,
    "b4":b4
    }
    return updated_parameters

# %%
def find_accuracy(y_actual,y_pred):
    accuracy = np.count_nonzero(np.argmax(y_pred,axis=0)==np.argmax(y_actual,axis=1))/y_actual.shape[0]
    return accuracy

# %%
def predict(X,Y,parameters):
    y_pred,cache=forward_propagation(X,parameters)
    return y_pred

# %%
def model1(dataset,layers_dims,num_epochs):
    m=len(dataset)
    num_batches=m/batch_size
    parameters=initialize_parameters(layers_dims)
    costs=[]
    acc=[]
    for epoch in range(num_epochs):
        for i in range(int(num_batches)):
            # Data loader
            loader = torch.utils.data.DataLoader(dataset=dataset,batch_size = batch_size ,shuffle=True)
            dataiter = iter(loader)
            data = next(dataiter)
            X,y = data
            X=X.numpy()
            y=y.numpy()
            # Flatten the images
            image_vector_size = 28*28
            X = X.reshape(X.shape[0], image_vector_size)
            y_one_hot=convert_to_onehot(y,num_classes)
            y_pred,cache=forward_propagation(X,parameters)
            cost=compute_cost(y_pred,y_one_hot.T)
            gradients=backward_propagation(X,y_one_hot.T,cache)
            parameters=update_parameter(parameters,gradients,learning_rate)
            if i%20==0:
                print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{int(num_batches)}], Loss: {cost.item():.4f}')
                costs.append(cost)
                acc.append(find_accuracy(y_one_hot,y_pred))
    return acc,costs,parameters

# %%
layers_dims=[784,500,250,100,10]
train_acc,train_costs,trained_parameters=model1(train_dataset,layers_dims,15)
# Out:
# Epoch [1/15], Step [1/937], Loss: 3.4988
# Epoch [1/15], Step [2/937], Loss: 3.4216
# Epoch [1/15], Step [3/937], Loss: 3.3850
# Epoch [1/15], Step [4/937], Loss: 3.5124
# Epoch [1/15], Step [5/937], Loss: 3.3217
# Epoch [1/15], Step [6/937], Loss: 3.3121
# Epoch [1/15], Step [7/937], Loss: 3.3589
# Epoch [1/15], Step [8/937], Loss: 3.3643
# Epoch [1/15], Step [9/937], Loss: 3.3723
# Epoch [1/15], Step [10/937], Loss: 3.3729
# Epoch [1/15], Step [11/937], Loss: 3.3411
# Epoch [1/15], Step [12/937], Loss: 3.3002
# Epoch [1/15], Step [13/937], Loss: 3.2853
# Epoch [1/15], Step [14/937], Loss: 3.2679
# Epoch [1/15], Step [15/937], Loss: 3.3250
# Epoch [1/15], Step [16/937], Loss: 3.3316
# Epoch [1/15], Step [17/937], Loss: 3.2522
# Epoch [1/15], Step [18/937], Loss: 3.3380
# Epoch [1/15], Step [19/937], Loss: 3.3158
# Epoch [1/15], Step [20/937], Loss: 3.3429
# Epoch [1/15], Step [21/937], Loss: 3.2879
# Epoch [1/15], Step [22/937], Loss: 3.3212
# Epoch [1/15], Step [23/937], Loss: 3.3572
# Epoch [1/15], Step [24/937], Loss: 3.2661
# Epoch [1/15], Step [25/937], Loss: 3.2147
# Epoch [1/15], Step [26/937], Loss: 3.2915
# Epoch [1/15], Step [27/937], Loss: 3.2405
# Epoch [1/15], Step [28/937], Loss: 3.2781
# Epoch [1/15], Step [29/937], Loss: 3.2718
# Epoch [1/15], Step [30/937], Loss: 3.2123
# Epoch [1/15], Step [31/937], Loss: 3.2705
# Epoch [1/15], Step [32/937], Loss: 3.2467
# Epoch [1/15], Step [33/937], Loss: 3.2668
# Epoch [1/15], Step [34/937], Loss: 3.2923
# Epoch [1/15], Step [35/937], Loss: 3.2793
# Epoch [1/15], Step [36/937], Loss: 3.2837
# Epoch [1/15], Step [37/937], Loss: 3.2551
# Epoch [1/15], Step [38/937], Loss: 3.2928
# Epoch [1/15], Step [39/937], Loss: 3.2640
# Epoch [1/15], Step [40/937], Loss: 3.2667
# Epoch [1/15], Step [41/937], Loss: 3.2620
# Epoch [1/15], Step [42/937], Loss: 3.2511
# Epoch [1/15], Step [43/937], Loss: 3.2523
# Epoch [1/15], Step [44/937], Loss: 3.2491
# Epoch [1/15], Step [45/937], Loss: 3.2361
# Epoch [1/15], Step [46/937], Loss: 3.2709
# Epoch [1/15], Step [47/937], Loss: 3.2468
# Epoch [1/15], Step [48/937], Loss: 3.2232
# Epoch [1/15], Step [49/937], Loss: 3.2495
# Epoch [1/15], Step [50/937], Loss: 3.2471
# Epoch [1/15], Step [51/937], Loss: 3.2529
# Epoch [1/15], Step [52/937], Loss: 3.2403
# Epoch [1/15], Step [53/937], Loss: 3.2504
# Epoch [1/15], Step [54/937], Loss: 3.2716
# Epoch [1/15], Step [55/937], Loss: 3.2292
# Epoch [1/15], Step [56/937], Loss: 3.2454
# Epoch [1/15], Step [57/937], Loss: 3.2332
# Epoch [1/15], Step [58/937], Loss: 3.2305
# Epoch [1/15], Step [59/937], Loss: 3.2641
# Epoch [1/15], Step [60/937], Loss: 3.2562
# Epoch [1/15], Step [61/937], Loss: 3.2459
# Epoch [1/15], Step [62/937], Loss: 3.2526
# Epoch [1/15], Step [63/937], Loss: 3.2306
# Epoch [1/15], Step [64/937], Loss: 3.2602
# Epoch [1/15], Step [65/937], Loss: 3.2362
# Epoch [1/15], Step [66/937], Loss: 3.2667
# Epoch [1/15], Step [67/937], Loss: 3.2634
# Epoch [1/15], Step [68/937], Loss: 3.2614
# Epoch [1/15], Step [69/937], Loss: 3.2490
# Epoch [1/15], Step [70/937], Loss: 3.2364
# Epoch [1/15], Step [71/937], Loss: 3.2689
# Epoch [1/15], Step [72/937], Loss: 3.2358
# Epoch [1/15], Step [73/937], Loss: 3.2681
# Epoch [1/15], Step [74/937], Loss: 3.2341
# Epoch [1/15], Step [75/937], Loss: 3.2608
# Epoch [1/15], Step [76/937], Loss: 3.2438
# Epoch [1/15], Step [77/937], Loss: 3.2561
# Epoch [1/15], Step [78/937], Loss: 3.2517
# Epoch [1/15], Step [79/937], Loss: 3.2337
# Epoch [1/15], Step [80/937], Loss: 3.2359
# Epoch [1/15], Step [81/937], Loss: 3.2655
# Epoch [1/15], Step [82/937], Loss: 3.2428
# Epoch [1/15], Step [83/937], Loss: 3.2538
# Epoch [1/15], Step [84/937], Loss: 3.2343
# Epoch [1/15], Step [85/937], Loss: 3.2534
# Epoch [1/15], Step [86/937], Loss: 3.2513
# Epoch [1/15], Step [87/937], Loss: 3.2463
# Epoch [1/15], Step [88/937], Loss: 3.2452
# Epoch [1/15], Step [89/937], Loss: 3.2482
# Epoch [1/15], Step [90/937], Loss: 3.2634
# Epoch [1/15], Step [91/937], Loss: 3.2479
# Epoch [1/15], Step [92/937], Loss: 3.2404
# Epoch [1/15], Step [93/937], Loss: 3.2562
# Epoch [1/15], Step [94/937], Loss: 3.2481
# Epoch [1/15], Step [95/937], Loss: 3.2316
# Epoch [1/15], Step [96/937], Loss: 3.2602
# Epoch [1/15], Step [97/937], Loss: 3.2371
# Epoch [1/15], Step [98/937], Loss: 3.2464
# Epoch [1/15], Step [99/937], Loss: 3.2840
# Epoch [1/15], Step [100/937], Loss: 3.2598
# Epoch [1/15], Step [101/937], Loss: 3.2473
# Epoch [1/15], Step [102/937], Loss: 3.2367
# Epoch [1/15], Step [103/937], Loss: 3.2396
# Epoch [1/15], Step [104/937], Loss: 3.2514
# Epoch [1/15], Step [105/937], Loss: 3.2481
# Epoch [1/15], Step [106/937], Loss: 3.2358
# Epoch [1/15], Step [107/937], Loss: 3.2525
# Epoch [1/15], Step [108/937], Loss: 3.2447
# Epoch [1/15], Step [109/937], Loss: 3.2492
# Epoch [1/15], Step [110/937], Loss: 3.2372
# Epoch [1/15], Step [111/937], Loss: 3.2462
# Epoch [1/15], Step [112/937], Loss: 3.2224
# Epoch [1/15], Step [113/937], Loss: 3.2292
# Epoch [1/15], Step [114/937], Loss: 3.2579
# Epoch [1/15], Step [115/937], Loss: 3.2628
# Epoch [1/15], Step [116/937], Loss: 3.2392
# Epoch [1/15], Step [117/937], Loss: 3.2502
# Epoch [1/15], Step [118/937], Loss: 3.2551
# Epoch [1/15], Step [119/937], Loss: 3.2314
# Epoch [1/15], Step [120/937], Loss: 3.2277
# Epoch [1/15], Step [121/937], Loss: 3.2679
# Epoch [1/15], Step [122/937], Loss: 3.2371
# Epoch [1/15], Step [123/937], Loss: 3.2627
# Epoch [1/15], Step [124/937], Loss: 3.2442
# Epoch [1/15], Step [125/937], Loss: 3.2036
# Epoch [1/15], Step [126/937], Loss: 3.2377
# Epoch [1/15], Step [127/937], Loss: 3.2890
# Epoch [1/15], Step [128/937], Loss: 3.2606
# Epoch [1/15], Step [129/937], Loss: 3.2345
# Epoch [1/15], Step [130/937], Loss: 3.2170
# Epoch [1/15], Step [131/937], Loss: 3.2534
# Epoch [1/15], Step [132/937], Loss: 3.2363
# Epoch [1/15], Step [133/937], Loss: 3.2402
# Epoch [1/15], Step [134/937], Loss: 3.2499
# Epoch [1/15], Step [135/937], Loss: 3.2517
# Epoch [1/15], Step [136/937], Loss: 3.2234
# Epoch [1/15], Step [137/937], Loss: 3.2391
# Epoch [1/15], Step [138/937], Loss: 3.2673
# Epoch [1/15], Step [139/937], Loss: 3.2491
# Epoch [1/15], Step [140/937], Loss: 3.2568
# Epoch [1/15], Step [141/937], Loss: 3.2572
# Epoch [1/15], Step [142/937], Loss: 3.2486
# Epoch [1/15], Step [143/937], Loss: 3.2343
# Epoch [1/15], Step [144/937], Loss: 3.2432
# Epoch [1/15], Step [145/937], Loss: 3.2444
# Epoch [1/15], Step [146/937], Loss: 3.2516
# Epoch [1/15], Step [147/937], Loss: 3.2466
# Epoch [1/15], Step [148/937], Loss: 3.2516
# Epoch [1/15], Step [149/937], Loss: 3.2291
# Epoch [1/15], Step [150/937], Loss: 3.2483
# Epoch [1/15], Step [151/937], Loss: 3.2552
# Epoch [1/15], Step [152/937], Loss: 3.2448
# Epoch [1/15], Step [153/937], Loss: 3.2575
# Epoch [1/15], Step [154/937], Loss: 3.2367
# Epoch [1/15], Step [155/937], Loss: 3.2535
# Epoch [1/15], Step [156/937], Loss: 3.2559
# Epoch [1/15], Step [157/937], Loss: 3.2657
# Epoch [1/15], Step [158/937], Loss: 3.2475
# Epoch [1/15], Step [159/937], Loss: 3.2535
# Epoch [1/15], Step [160/937], Loss: 3.2559
# Epoch [1/15], Step [161/937], Loss: 3.2426
# Epoch [1/15], Step [162/937], Loss: 3.2430
# Epoch [1/15], Step [163/937], Loss: 3.2440
# Epoch [1/15], Step [164/937], Loss: 3.2299
# Epoch [1/15], Step [165/937], Loss: 3.2309
# Epoch [1/15], Step [166/937], Loss: 3.2600
# Epoch [1/15], Step [167/937], Loss: 3.2301
# Epoch [1/15], Step [168/937], Loss: 3.2505
# Epoch [1/15], Step [169/937], Loss: 3.2450
# Epoch [1/15], Step [170/937], Loss: 3.2361
# Epoch [1/15], Step [171/937], Loss: 3.2331
# Epoch [1/15], Step [172/937], Loss: 3.2381
# Epoch [1/15], Step [173/937], Loss: 3.2550
# Epoch [1/15], Step [174/937], Loss: 3.2400
# Epoch [1/15], Step [175/937], Loss: 3.2248
# Epoch [1/15], Step [176/937], Loss: 3.2626
# Epoch [1/15], Step [177/937], Loss: 3.2492
# Epoch [1/15], Step [178/937], Loss: 3.2712
# Epoch [1/15], Step [179/937], Loss: 3.2503
# Epoch [1/15], Step [180/937], Loss: 3.2369
# Epoch [1/15], Step [181/937], Loss: 3.2438
# Epoch [1/15], Step [182/937], Loss: 3.2430
# Epoch [1/15], Step [183/937], Loss: 3.2396
# Epoch [1/15], Step [184/937], Loss: 3.2480
# Epoch [1/15], Step [185/937], Loss: 3.2416
# Epoch [1/15], Step [186/937], Loss: 3.2411
# Epoch [1/15], Step [187/937], Loss: 3.2398
# Epoch [1/15], Step [188/937], Loss: 3.2462
# Epoch [1/15], Step [189/937], Loss: 3.2505
# Epoch [1/15], Step [190/937], Loss: 3.2491
# Epoch [1/15], Step [191/937], Loss: 3.2407
# Epoch [1/15], Step [192/937], Loss: 3.2455
# Epoch [1/15], Step [193/937], Loss: 3.2679
# Epoch [1/15], Step [194/937], Loss: 3.2624
# Epoch [1/15], Step [195/937], Loss: 3.2463
# Epoch [1/15], Step [196/937], Loss: 3.2510
# Epoch [1/15], Step [197/937], Loss: 3.2451
# Epoch [1/15], Step [198/937], Loss: 3.2489
# Epoch [1/15], Step [199/937], Loss: 3.2427
# Epoch [1/15], Step [200/937], Loss: 3.2438
# Epoch [1/15], Step [201/937], Loss: 3.2525
# Epoch [1/15], Step [202/937], Loss: 3.2340
# Epoch [1/15], Step [203/937], Loss: 3.2387
# Epoch [1/15], Step [204/937], Loss: 3.2505
# Epoch [1/15], Step [205/937], Loss: 3.2474
# Epoch [1/15], Step [206/937], Loss: 3.2288
# Epoch [1/15], Step [207/937], Loss: 3.2434
# Epoch [1/15], Step [208/937], Loss: 3.2274
# Epoch [1/15], Step [209/937], Loss: 3.2212
# Epoch [1/15], Step [210/937], Loss: 3.2457
# Epoch [1/15], Step [211/937], Loss: 3.2394
# Epoch [1/15], Step [212/937], Loss: 3.2491
# Epoch [1/15], Step [213/937], Loss: 3.2694
# Epoch [1/15], Step [214/937], Loss: 3.2522
# Epoch [1/15], Step [215/937], Loss: 3.2600
# Epoch [1/15], Step [216/937], Loss: 3.2412
# Epoch [1/15], Step [217/937], Loss: 3.2203
# Epoch [1/15], Step [218/937], Loss: 3.2577
# Epoch [1/15], Step [219/937], Loss: 3.2225
# Epoch [1/15], Step [335/937], Loss: 3.2503
# Epoch [1/15], Step [336/937], Loss: 3.2351
# Epoch [1/15], Step [337/937], Loss: 3.2382
# Epoch [1/15], Step [338/937], Loss: 3.2495
# Epoch [1/15], Step [339/937], Loss: 3.2539
# Epoch [1/15], Step [340/937], Loss: 3.2568
# Epoch [1/15], Step [341/937], Loss: 3.2410
# Epoch [1/15], Step [342/937], Loss: 3.2398
# Epoch [1/15], Step [343/937], Loss: 3.2423
# Epoch [1/15], Step [344/937], Loss: 3.2288
# Epoch [1/15], Step [345/937], Loss: 3.2340
# Epoch [1/15], Step [346/937], Loss: 3.2544
# Epoch [1/15], Step [347/937], Loss: 3.2308
# Epoch [1/15], Step [348/937], Loss: 3.2528
# Epoch [1/15], Step [349/937], Loss: 3.2565
# Epoch [1/15], Step [350/937], Loss: 3.2588
# Epoch [1/15], Step [351/937], Loss: 3.2494
# Epoch [1/15], Step [352/937], Loss: 3.2590
# Epoch [1/15], Step [353/937], Loss: 3.2442
# Epoch [1/15], Step [354/937], Loss: 3.2529
# Epoch [1/15], Step [355/937], Loss: 3.2515
# Epoch [1/15], Step [356/937], Loss: 3.2387
# Epoch [1/15], Step [357/937], Loss: 3.2443
# Epoch [1/15], Step [358/937], Loss: 3.2463
# Epoch [1/15], Step [359/937], Loss: 3.2439
# Epoch [1/15], Step [360/937], Loss: 3.2415
# Epoch [1/15], Step [361/937], Loss: 3.2558
# Epoch [1/15], Step [362/937], Loss: 3.2521
# Epoch [1/15], Step [363/937], Loss: 3.2405
# Epoch [1/15], Step [364/937], Loss: 3.2387
# Epoch [1/15], Step [365/937], Loss: 3.2388
# Epoch [1/15], Step [366/937], Loss: 3.2307
# Epoch [1/15], Step [367/937], Loss: 3.2449
# Epoch [1/15], Step [368/937], Loss: 3.2383
# Epoch [1/15], Step [369/937], Loss: 3.2432
# Epoch [1/15], Step [370/937], Loss: 3.2352
# Epoch [1/15], Step [371/937], Loss: 3.2469
# Epoch [1/15], Step [372/937], Loss: 3.2536
# Epoch [1/15], Step [373/937], Loss: 3.2356
# Epoch [1/15], Step [374/937], Loss: 3.2535
# Epoch [1/15], Step [375/937], Loss: 3.2462
# Epoch [1/15], Step [376/937], Loss: 3.2446
# Epoch [1/15], Step [377/937], Loss: 3.2509
# Epoch [1/15], Step [378/937], Loss: 3.2468
# Epoch [1/15], Step [379/937], Loss: 3.2290
# Epoch [1/15], Step [380/937], Loss: 3.2539
# Epoch [1/15], Step [381/937], Loss: 3.2440
# Epoch [1/15], Step [382/937], Loss: 3.2429
# Epoch [1/15], Step [383/937], Loss: 3.2434
# Epoch [1/15], Step [384/937], Loss: 3.2395
# Epoch [1/15], Step [385/937], Loss: 3.2337
# Epoch [1/15], Step [386/937], Loss: 3.2595
# Epoch [1/15], Step [387/937], Loss: 3.2299
# Epoch [1/15], Step [388/937], Loss: 3.2427
# Epoch [1/15], Step [389/937], Loss: 3.2386
# Epoch [1/15], Step [390/937], Loss: 3.2435
# Epoch [1/15], Step [391/937], Loss: 3.2445
# Epoch [1/15], Step [392/937], Loss: 3.2327
# Epoch [1/15], Step [393/937], Loss: 3.2376
# Epoch [1/15], Step [394/937], Loss: 3.2290
# Epoch [1/15], Step [395/937], Loss: 3.2466
# Epoch [1/15], Step [396/937], Loss: 3.2140
# Epoch [1/15], Step [397/937], Loss: 3.2452
# Epoch [1/15], Step [398/937], Loss: 3.2701
# Epoch [1/15], Step [399/937], Loss: 3.2400
# Epoch [1/15], Step [400/937], Loss: 3.2324
# Epoch [1/15], Step [401/937], Loss: 3.2465
# Epoch [1/15], Step [402/937], Loss: 3.2480
# Epoch [1/15], Step [403/937], Loss: 3.2381
# Epoch [1/15], Step [404/937], Loss: 3.2444
# Epoch [1/15], Step [405/937], Loss: 3.2507
# Epoch [1/15], Step [406/937], Loss: 3.2508
# Epoch [1/15], Step [407/937], Loss: 3.2425
# Epoch [1/15], Step [408/937], Loss: 3.2392
# Epoch [1/15], Step [409/937], Loss: 3.2243
# Epoch [1/15], Step [410/937], Loss: 3.2269
# Epoch [1/15], Step [411/937], Loss: 3.2748
# Epoch [1/15], Step [412/937], Loss: 3.2652
# Epoch [1/15], Step [413/937], Loss: 3.2422
# Epoch [1/15], Step [414/937], Loss: 3.2449
# Epoch [1/15], Step [415/937], Loss: 3.2518
# Epoch [1/15], Step [416/937], Loss: 3.2441
# Epoch [1/15], Step [417/937], Loss: 3.2442
# Epoch [1/15], Step [418/937], Loss: 3.2531
# Epoch [1/15], Step [419/937], Loss: 3.2419
# Epoch [1/15], Step [420/937], Loss: 3.2362
# Epoch [1/15], Step [421/937], Loss: 3.2559
# Epoch [1/15], Step [422/937], Loss: 3.2389
# Epoch [1/15], Step [423/937], Loss: 3.2554
# Epoch [1/15], Step [424/937], Loss: 3.2408
# Epoch [1/15], Step [425/937], Loss: 3.2263
# Epoch [1/15], Step [426/937], Loss: 3.2318
# Epoch [1/15], Step [427/937], Loss: 3.2400
# Epoch [1/15], Step [428/937], Loss: 3.2457
# Epoch [1/15], Step [429/937], Loss: 3.2436
# Epoch [1/15], Step [430/937], Loss: 3.2364
# Epoch [1/15], Step [431/937], Loss: 3.2491
# Epoch [1/15], Step [432/937], Loss: 3.2262
# Epoch [1/15], Step [433/937], Loss: 3.2563
# Epoch [1/15], Step [434/937], Loss: 3.2518
# Epoch [1/15], Step [435/937], Loss: 3.2560
# Epoch [1/15], Step [436/937], Loss: 3.2401
# Epoch [1/15], Step [437/937], Loss: 3.2385
# Epoch [1/15], Step [438/937], Loss: 3.2551
# Epoch [1/15], Step [439/937], Loss: 3.2530
# Epoch [1/15], Step [440/937], Loss: 3.2412
# Epoch [1/15], Step [441/937], Loss: 3.2390
# Epoch [1/15], Step [442/937], Loss: 3.2562
# Epoch [1/15], Step [443/937], Loss: 3.2521
# Epoch [1/15], Step [444/937], Loss: 3.2402
# Epoch [1/15], Step [445/937], Loss: 3.2475
# Epoch [1/15], Step [446/937], Loss: 3.2404
# Epoch [1/15], Step [447/937], Loss: 3.2507
# Epoch [1/15], Step [448/937], Loss: 3.2477
# Epoch [1/15], Step [449/937], Loss: 3.2480
# Epoch [1/15], Step [450/937], Loss: 3.2439
# Epoch [1/15], Step [451/937], Loss: 3.2408
# Epoch [1/15], Step [452/937], Loss: 3.2463
# Epoch [1/15], Step [453/937], Loss: 3.2426
# Epoch [1/15], Step [454/937], Loss: 3.2421
# Epoch [1/15], Step [455/937], Loss: 3.2345
# Epoch [1/15], Step [456/937], Loss: 3.2436
# Epoch [1/15], Step [457/937], Loss: 3.2435
# Epoch [1/15], Step [458/937], Loss: 3.2513
# Epoch [1/15], Step [459/937], Loss: 3.2221
# Epoch [1/15], Step [460/937], Loss: 3.2513
# Epoch [1/15], Step [461/937], Loss: 3.2331
# Epoch [1/15], Step [462/937], Loss: 3.2454
# Epoch [1/15], Step [463/937], Loss: 3.2451
# Epoch [1/15], Step [464/937], Loss: 3.2663
# Epoch [1/15], Step [465/937], Loss: 3.2424
# Epoch [1/15], Step [466/937], Loss: 3.2453
# Epoch [1/15], Step [467/937], Loss: 3.2378
# Epoch [1/15], Step [468/937], Loss: 3.2280
# Epoch [1/15], Step [469/937], Loss: 3.2526
# Epoch [1/15], Step [470/937], Loss: 3.2471
# Epoch [1/15], Step [471/937], Loss: 3.2415
# Epoch [1/15], Step [472/937], Loss: 3.2553
# Epoch [1/15], Step [473/937], Loss: 3.2446
# Epoch [1/15], Step [474/937], Loss: 3.2515
# Epoch [1/15], Step [475/937], Loss: 3.2475
# Epoch [1/15], Step [476/937], Loss: 3.2312
# Epoch [1/15], Step [477/937], Loss: 3.2419
# Epoch [1/15], Step [478/937], Loss: 3.2301
# Epoch [1/15], Step [479/937], Loss: 3.2296
# Epoch [1/15], Step [480/937], Loss: 3.2348
# Epoch [1/15], Step [481/937], Loss: 3.2570
# Epoch [1/15], Step [482/937], Loss: 3.2420
# Epoch [1/15], Step [483/937], Loss: 3.2437
# Epoch [1/15], Step [484/937], Loss: 3.2455
# Epoch [1/15], Step [485/937], Loss: 3.2518
# Epoch [1/15], Step [486/937], Loss: 3.2397
# Epoch [1/15], Step [487/937], Loss: 3.2568
# Epoch [1/15], Step [488/937], Loss: 3.2417
# Epoch [1/15], Step [489/937], Loss: 3.2473
# Epoch [1/15], Step [490/937], Loss: 3.2431
# Epoch [1/15], Step [491/937], Loss: 3.2359
# Epoch [1/15], Step [492/937], Loss: 3.2457
# Epoch [1/15], Step [493/937], Loss: 3.2401
# Epoch [1/15], Step [494/937], Loss: 3.2441
# Epoch [1/15], Step [495/937], Loss: 3.2353
# Epoch [1/15], Step [496/937], Loss: 3.2379
# Epoch [1/15], Step [497/937], Loss: 3.2355
# Epoch [1/15], Step [498/937], Loss: 3.2610
# Epoch [1/15], Step [499/937], Loss: 3.2427
# Epoch [1/15], Step [500/937], Loss: 3.2470
# Epoch [1/15], Step [501/937], Loss: 3.2414
# Epoch [1/15], Step [502/937], Loss: 3.2231
# Epoch [1/15], Step [503/937], Loss: 3.2412
# Epoch [1/15], Step [504/937], Loss: 3.2423
# Epoch [1/15], Step [505/937], Loss: 3.2496
# Epoch [1/15], Step [506/937], Loss: 3.2341
# Epoch [1/15], Step [622/937], Loss: 3.2380
# Epoch [1/15], Step [623/937], Loss: 3.2276
# Epoch [1/15], Step [624/937], Loss: 3.2197
# Epoch [1/15], Step [625/937], Loss: 3.2494
# Epoch [1/15], Step [626/937], Loss: 3.2435
# Epoch [1/15], Step [627/937], Loss: 3.2055
# Epoch [1/15], Step [628/937], Loss: 3.2429
# Epoch [1/15], Step [629/937], Loss: 3.2687
# Epoch [1/15], Step [630/937], Loss: 3.2525
# Epoch [1/15], Step [631/937], Loss: 3.2382
# Epoch [1/15], Step [632/937], Loss: 3.2339
# Epoch [1/15], Step [633/937], Loss: 3.2403
# Epoch [1/15], Step [634/937], Loss: 3.2311
# Epoch [1/15], Step [635/937], Loss: 3.2367
# Epoch [1/15], Step [636/937], Loss: 3.2631
# Epoch [1/15], Step [637/937], Loss: 3.2349
# Epoch [1/15], Step [638/937], Loss: 3.2344
# Epoch [1/15], Step [639/937], Loss: 3.2887
# Epoch [1/15], Step [640/937], Loss: 3.2354
# Epoch [1/15], Step [641/937], Loss: 3.2518
# Epoch [1/15], Step [642/937], Loss: 3.2228
# Epoch [1/15], Step [643/937], Loss: 3.2425
# Epoch [1/15], Step [644/937], Loss: 3.2601
# Epoch [1/15], Step [645/937], Loss: 3.2336
# Epoch [1/15], Step [646/937], Loss: 3.2414
# Epoch [1/15], Step [647/937], Loss: 3.2247
# Epoch [1/15], Step [648/937], Loss: 3.2469
# Epoch [1/15], Step [649/937], Loss: 3.2361
# Epoch [1/15], Step [650/937], Loss: 3.2313
# Epoch [1/15], Step [651/937], Loss: 3.2291
# Epoch [1/15], Step [652/937], Loss: 3.2364
# Epoch [1/15], Step [653/937], Loss: 3.2451
# Epoch [1/15], Step [654/937], Loss: 3.2347
# Epoch [1/15], Step [655/937], Loss: 3.2348
# Epoch [1/15], Step [656/937], Loss: 3.2394
# Epoch [1/15], Step [657/937], Loss: 3.2212
# Epoch [1/15], Step [658/937], Loss: 3.2181
# Epoch [1/15], Step [659/937], Loss: 3.2550
# Epoch [1/15], Step [660/937], Loss: 3.2763
# Epoch [1/15], Step [661/937], Loss: 3.2295
# Epoch [1/15], Step [662/937], Loss: 3.2359
# Epoch [1/15], Step [663/937], Loss: 3.2257
# Epoch [1/15], Step [664/937], Loss: 3.2590
# Epoch [1/15], Step [665/937], Loss: 3.2417
# Epoch [1/15], Step [666/937], Loss: 3.2278
# Epoch [1/15], Step [667/937], Loss: 3.2503
# Epoch [1/15], Step [668/937], Loss: 3.2475
# Epoch [1/15], Step [669/937], Loss: 3.2570
# Epoch [1/15], Step [670/937], Loss: 3.2240
# Epoch [1/15], Step [671/937], Loss: 3.2459
# Epoch [1/15], Step [672/937], Loss: 3.2547
# Epoch [1/15], Step [673/937], Loss: 3.2328
# Epoch [1/15], Step [674/937], Loss: 3.2325
# Epoch [1/15], Step [675/937], Loss: 3.2241
# Epoch [1/15], Step [676/937], Loss: 3.2340
# Epoch [1/15], Step [677/937], Loss: 3.2563
# Epoch [1/15], Step [678/937], Loss: 3.2328
# Epoch [1/15], Step [679/937], Loss: 3.2450
# Epoch [1/15], Step [680/937], Loss: 3.2480
# Epoch [1/15], Step [681/937], Loss: 3.2350
# Epoch [1/15], Step [682/937], Loss: 3.2262
# Epoch [1/15], Step [683/937], Loss: 3.2440
# Epoch [1/15], Step [684/937], Loss: 3.2255
# Epoch [1/15], Step [685/937], Loss: 3.2604
# Epoch [1/15], Step [686/937], Loss: 3.2245
# Epoch [1/15], Step [687/937], Loss: 3.2273
# Epoch [1/15], Step [688/937], Loss: 3.2683
# Epoch [1/15], Step [689/937], Loss: 3.2476
# Epoch [1/15], Step [690/937], Loss: 3.2487
# Epoch [1/15], Step [691/937], Loss: 3.2405
# Epoch [1/15], Step [692/937], Loss: 3.2477
# Epoch [1/15], Step [693/937], Loss: 3.2356
# Epoch [1/15], Step [694/937], Loss: 3.2372
# Epoch [1/15], Step [695/937], Loss: 3.2165
# Epoch [1/15], Step [696/937], Loss: 3.2439
# Epoch [1/15], Step [697/937], Loss: 3.2561
# Epoch [1/15], Step [698/937], Loss: 3.2333
# Epoch [1/15], Step [699/937], Loss: 3.2409
# Epoch [1/15], Step [700/937], Loss: 3.2296
# Epoch [1/15], Step [701/937], Loss: 3.2432
# Epoch [1/15], Step [702/937], Loss: 3.2443
# Epoch [1/15], Step [703/937], Loss: 3.2373
# Epoch [1/15], Step [704/937], Loss: 3.2389
# Epoch [1/15], Step [705/937], Loss: 3.2498
# Epoch [1/15], Step [706/937], Loss: 3.2381
# Epoch [1/15], Step [707/937], Loss: 3.2434
# Epoch [1/15], Step [708/937], Loss: 3.2406
# Epoch [1/15], Step [709/937], Loss: 3.2484
# Epoch [1/15], Step [710/937], Loss: 3.2353
# Epoch [1/15], Step [711/937], Loss: 3.2408
# Epoch [1/15], Step [712/937], Loss: 3.2570
# Epoch [1/15], Step [713/937], Loss: 3.2359
# Epoch [1/15], Step [714/937], Loss: 3.2408
# Epoch [1/15], Step [715/937], Loss: 3.2498
# Epoch [1/15], Step [716/937], Loss: 3.2479
# Epoch [1/15], Step [717/937], Loss: 3.2388
# Epoch [1/15], Step [718/937], Loss: 3.2359
# Epoch [1/15], Step [719/937], Loss: 3.2487
# Epoch [1/15], Step [720/937], Loss: 3.2364
# Epoch [1/15], Step [721/937], Loss: 3.2398
# Epoch [1/15], Step [722/937], Loss: 3.2281
# Epoch [1/15], Step [723/937], Loss: 3.2333
# Epoch [1/15], Step [724/937], Loss: 3.2488
# Epoch [1/15], Step [725/937], Loss: 3.2368
# Epoch [1/15], Step [726/937], Loss: 3.2455
# Epoch [1/15], Step [727/937], Loss: 3.2187
# Epoch [1/15], Step [728/937], Loss: 3.2425
# Epoch [1/15], Step [729/937], Loss: 3.2326
# Epoch [1/15], Step [730/937], Loss: 3.2359
# Epoch [1/15], Step [731/937], Loss: 3.2512
# Epoch [1/15], Step [732/937], Loss: 3.2299
# Epoch [1/15], Step [733/937], Loss: 3.2391
# Epoch [1/15], Step [734/937], Loss: 3.2511
# Epoch [1/15], Step [735/937], Loss: 3.2424
# Epoch [1/15], Step [736/937], Loss: 3.2353
# Epoch [1/15], Step [737/937], Loss: 3.2511
# Epoch [1/15], Step [738/937], Loss: 3.2331
# Epoch [1/15], Step [739/937], Loss: 3.2276
# Epoch [1/15], Step [740/937], Loss: 3.2532
# Epoch [1/15], Step [741/937], Loss: 3.2324
# Epoch [1/15], Step [742/937], Loss: 3.2487
# Epoch [1/15], Step [743/937], Loss: 3.2293
# Epoch [1/15], Step [744/937], Loss: 3.2480
# Epoch [1/15], Step [745/937], Loss: 3.2449
# Epoch [1/15], Step [746/937], Loss: 3.2420
# Epoch [1/15], Step [747/937], Loss: 3.2384
# Epoch [1/15], Step [748/937], Loss: 3.2399
# Epoch [1/15], Step [749/937], Loss: 3.2476
# Epoch [1/15], Step [750/937], Loss: 3.2289
# Epoch [1/15], Step [751/937], Loss: 3.2398
# Epoch [1/15], Step [752/937], Loss: 3.2505
# Epoch [1/15], Step [753/937], Loss: 3.2320
# Epoch [1/15], Step [754/937], Loss: 3.2373
# Epoch [1/15], Step [755/937], Loss: 3.2287
# Epoch [1/15], Step [756/937], Loss: 3.2349
# Epoch [1/15], Step [757/937], Loss: 3.2294
# Epoch [1/15], Step [758/937], Loss: 3.2476
# Epoch [1/15], Step [759/937], Loss: 3.2202
# Epoch [1/15], Step [760/937], Loss: 3.2296
# Epoch [1/15], Step [761/937], Loss: 3.2210
# Epoch [1/15], Step [762/937], Loss: 3.2357
# Epoch [1/15], Step [763/937], Loss: 3.2559
# Epoch [1/15], Step [764/937], Loss: 3.2287
# Epoch [1/15], Step [765/937], Loss: 3.2536
# Epoch [1/15], Step [766/937], Loss: 3.2239
# Epoch [1/15], Step [767/937], Loss: 3.2326
# Epoch [1/15], Step [768/937], Loss: 3.2440
# Epoch [1/15], Step [769/937], Loss: 3.2361
# Epoch [1/15], Step [770/937], Loss: 3.2175
# Epoch [1/15], Step [771/937], Loss: 3.2358
# Epoch [1/15], Step [772/937], Loss: 3.2323
# Epoch [1/15], Step [773/937], Loss: 3.2320
# Epoch [1/15], Step [774/937], Loss: 3.2357
# Epoch [1/15], Step [775/937], Loss: 3.2576
# Epoch [1/15], Step [776/937], Loss: 3.2268
# Epoch [1/15], Step [777/937], Loss: 3.2364
# Epoch [1/15], Step [778/937], Loss: 3.2376
# Epoch [1/15], Step [779/937], Loss: 3.2220
# Epoch [1/15], Step [780/937], Loss: 3.2182
# Epoch [1/15], Step [781/937], Loss: 3.2519
# Epoch [1/15], Step [782/937], Loss: 3.2279
# Epoch [1/15], Step [783/937], Loss: 3.2245
# Epoch [1/15], Step [784/937], Loss: 3.2397
# Epoch [1/15], Step [785/937], Loss: 3.2602
# Epoch [1/15], Step [786/937], Loss: 3.2597
# Epoch [1/15], Step [787/937], Loss: 3.2324
# Epoch [1/15], Step [788/937], Loss: 3.2409
# Epoch [1/15], Step [789/937], Loss: 3.2413
# Epoch [1/15], Step [790/937], Loss: 3.2238
# Epoch [1/15], Step [791/937], Loss: 3.2345
# Epoch [1/15], Step [792/937], Loss: 3.2452
# Epoch [1/15], Step [793/937], Loss: 3.2472
# Epoch [1/15], Step [794/937], Loss: 3.2421
# Epoch [1/15], Step [795/937], Loss: 3.2382
# Epoch [1/15], Step [796/937], Loss: 3.2284
# Epoch [1/15], Step [797/937], Loss: 3.2231
# Epoch [1/15], Step [798/937], Loss: 3.2542
# Epoch [1/15], Step [799/937], Loss: 3.2245
# Epoch [1/15], Step [800/937], Loss: 3.2280
# Epoch [1/15], Step [801/937], Loss: 3.2503
# Epoch [1/15], Step [802/937], Loss: 3.2315
# Epoch [1/15], Step [803/937], Loss: 3.2378
# Epoch [1/15], Step [804/937], Loss: 3.2242
# Epoch [1/15], Step [805/937], Loss: 3.2166
# Epoch [1/15], Step [806/937], Loss: 3.2390
# Epoch [1/15], Step [807/937], Loss: 3.2593
# Epoch [1/15], Step [808/937], Loss: 3.2324
# Epoch [1/15], Step [809/937], Loss: 3.2449
# Epoch [1/15], Step [810/937], Loss: 3.2324
# Epoch [1/15], Step [811/937], Loss: 3.2391
# Epoch [1/15], Step [812/937], Loss: 3.2458
# Epoch [1/15], Step [813/937], Loss: 3.2330
# Epoch [1/15], Step [814/937], Loss: 3.2098
# Epoch [1/15], Step [815/937], Loss: 3.2278
# Epoch [1/15], Step [816/937], Loss: 3.2427
# Epoch [1/15], Step [817/937], Loss: 3.2449
# Epoch [1/15], Step [818/937], Loss: 3.2483
# Epoch [1/15], Step [819/937], Loss: 3.2494
# Epoch [1/15], Step [820/937], Loss: 3.2155
# Epoch [1/15], Step [821/937], Loss: 3.2650
# Epoch [1/15], Step [822/937], Loss: 3.2319
# Epoch [1/15], Step [823/937], Loss: 3.2449
# Epoch [1/15], Step [824/937], Loss: 3.2221
# Epoch [1/15], Step [825/937], Loss: 3.2348
# Epoch [1/15], Step [826/937], Loss: 3.2359
# Epoch [1/15], Step [827/937], Loss: 3.2396
# Epoch [1/15], Step [828/937], Loss: 3.2261
# Epoch [1/15], Step [829/937], Loss: 3.2156
# Epoch [1/15], Step [830/937], Loss: 3.2337
# Epoch [1/15], Step [831/937], Loss: 3.2281
# Epoch [1/15], Step [832/937], Loss: 3.2288
# Epoch [1/15], Step [833/937], Loss: 3.2142
# Epoch [1/15], Step [834/937], Loss: 3.2509
# Epoch [1/15], Step [835/937], Loss: 3.2505
# Epoch [1/15], Step [836/937], Loss: 3.2477
# Epoch [1/15], Step [837/937], Loss: 3.2486
# Epoch [1/15], Step [838/937], Loss: 3.2422
# Epoch [1/15], Step [839/937], Loss: 3.2504
# Epoch [1/15], Step [840/937], Loss: 3.2360
# Epoch [1/15], Step [841/937], Loss: 3.2473
# Epoch [1/15], Step [842/937], Loss: 3.2266
# Epoch [1/15], Step [843/937], Loss: 3.2279
# Epoch [1/15], Step [844/937], Loss: 3.2419
# Epoch [1/15], Step [845/937], Loss: 3.2422
# Epoch [1/15], Step [846/937], Loss: 3.2309
# Epoch [1/15], Step [847/937], Loss: 3.2360
# Epoch [1/15], Step [848/937], Loss: 3.2560
# Epoch [1/15], Step [849/937], Loss: 3.2402
# Epoch [1/15], Step [850/937], Loss: 3.2415
# Epoch [1/15], Step [851/937], Loss: 3.2489
# Epoch [15/15], Step [936/937], Loss: 0.8750
# Epoch [15/15], Step [937/937], Loss: 1.2263

# %%
p=len(test_dataset)
test_batches=p/batch_size
# test_costs=[]
# test_accuracy=[]
# for i in range(int(test_batches)):
loader = torch.utils.data.DataLoader(dataset=test_dataset,batch_size = p ,shuffle=True)
dataiter = iter(loader)
data = next(dataiter)
X,y = data

X=X.numpy()
y=y.numpy()
# Flatten the images
image_vector_size = 28*28
X = X.reshape(X.shape[0], image_vector_size)
y_one_hot=convert_to_onehot(y,num_classes)
y_hat,out_cache=forward_propagation(X,trained_parameters)
#     test_costs.append(compute_cost(y_hat,y_one_hot.T))
#     test_accuracy.append(find_accuracy(y_one_hot,y_hat))
test_accuracy=find_accuracy(y_one_hot,y_hat)
test_cost=compute_cost(y_hat,y_one_hot.T)

# %%
k = np.argmax(y_hat,axis=0)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(k, y)
# Out:
# array([[ 950,    0,   15,    4,    2,   21,   24,    7,   10,   13],
#        [   0, 1111,   20,    8,    4,    3,    3,   34,   20,    5],
#        [   3,    4,  863,   25,    3,   12,   12,   18,   16,    2],
#        [   1,    6,   30,  856,    0,  101,    0,    1,   42,    7],
#        [   2,    0,   20,    1,  796,   16,   14,    4,   20,   92],
#        [  15,    1,    3,   44,    2,  656,   22,    2,   51,   15],
#        [   6,    3,   31,    1,   21,   29,  882,    0,   19,    0],
#        [   1,    1,   11,   24,    0,   11,    0,  900,   12,   63],
#        [   2,    8,   31,   40,    7,   23,    1,    7,  755,    9],
#        [   0,    1,    8,    7,  147,   20,    0,   55,   29,  803]],
#       dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize=(8,8))
sn.heatmap(confusion_matrix(k, y),annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('truth')
# Out:
# Text(51.0, 0.5, 'truth')

# %%
y_hat.shape
# Out:
# (10, 10000)

# %%
print(train_acc[-1])
# Out:
# 0.828125

# %%
print(test_accuracy)
# Out:
# 0.8572

# %%
plt.plot(train_costs)
plt.xlabel('train_loss')
plt.ylabel('number of iterations')
plt.show()

# %%
plt.plot(train_acc)

plt.show()

# %%
m=len(train_dataset)
train_batches=m/batch_size
# test_costs=[]
# test_accuracy=[]
# for i in range(int(test_batches)):
loader = torch.utils.data.DataLoader(dataset=train_dataset,batch_size = m ,shuffle=True)
dataiter = iter(loader)
data = next(dataiter)
X_train,y_train = data

X_train=X_train.numpy()
y_train=y_train.numpy()
# Flatten the images
image_vector_size = 28*28
X_train = X_train.reshape(X_train.shape[0], image_vector_size)
y_train_one_hot=convert_to_onehot(y_train,num_classes)
y_train_hat,out_train_cache=forward_propagation(X_train,trained_parameters)
#     test_costs.append(compute_cost(y_hat,y_one_hot.T))
#     test_accuracy.append(find_accuracy(y_one_hot,y_hat))
train_accuracy_final=find_accuracy(y_train_one_hot,y_train_hat)
train_cost_final=compute_cost(y_train_hat,y_train_one_hot.T)

# %%
print(train_accuracy_final)
# Out:
# 0.85455

# %%
print(train_cost_final)
# Out:
# 0.8837430341174046
